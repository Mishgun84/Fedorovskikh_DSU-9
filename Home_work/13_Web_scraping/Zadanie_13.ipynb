# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга и работы с API"

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Будем парсить страницу со свежеми новостям на https://habr.com/ru/all/.
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# KEYWORDS = ['python', 'парсинг']
#
# Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм вида: <дата> - <заголовок> - <ссылка>

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
KEYWORDS = ['JSON', 'python', 'pact', 'UTM', 'DNS', 'HTML']
res = requests.get('https://habr.com/ru/all/')

# %%
soup = BeautifulSoup(res.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html data-vue-meta="%7B%22lang%22:%7B%22ssr%22:%22ru%22%7D%7D" lang="ru">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1.0,viewport-fit=cover" name="viewport"/>
# <title>Все публикации подряд / Хабр</title>
# <style>
#     /* cyrillic-ext */
#     @font-face {
#       font-family: 'Fira Sans';
#       font-style: normal;
#       font-weight: 500;
#       font-display: swap;
#       src: url(https://fonts.gstatic.com/s/firasans/v11/va9B4kDNxMZdWfMOD5VnZKveSxf6TF0.woff2) format('woff2');
#       unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;
#     }
#
#     /* cyrillic */
#     @font-face {
#       font-family: 'Fira Sans';
#       font-style: normal;
#       font-weight: 500;
#       font-display: swap;
#       src: url(https://fonts.gstatic.com/s/firasans/v11/va9B4kDNxMZdWfMOD5VnZKveQhf6TF0.woff2) format('woff2');
#       unicode-range: U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;
#     }
#
#     /* latin-ext */
#     @font-face {
#       font-family: 'Fira Sans';
#       font-style: normal;
#       font-weight: 500;
#       font-display: swap;
#       src: url(https://fonts.gstatic.com/s/firasans/v11/va9B4kDNxMZdWfMOD5VnZKveSBf6TF0.woff2) format('woff2');
#       unicode-range: U+0100-024F, U+0259, U+1E00-1EFF, U+2020, U+20A0-20AB, U+20AD-20CF, U+2113, U+2C60-2C7F, U+A720-A7FF;
#     }
#
#     /* latin */
#     @font-face {
#       font-family: 'Fira Sans';
#       font-style: normal;
#       font-weight: 500;
#       font-display: swap;
#       src: url(https://fonts.gstatic.com/s/firasans/v11/va9B4kDNxMZdWfMOD5VnZKveRhf6.woff2) format('woff2');
#       unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
#     }
#   </style>
# <link as="style" href="https://assets.habr.com/habr-web/css/chunk-vendors.db52f5c6.css" rel="preload"/><link as="script" href="https://assets.habr.com/habr-web/js/chunk-vendors.9e4ba848.js" rel="preload"/><link as="style" href="https://assets.habr.com/habr-web/css/app.ac61f8eb.css" rel="preload"/><link as="script" href="https://assets.habr.com/habr-web/js/app.5d04126c.js" rel="preload"/><link as="style" href="https://assets.habr.com/habr-web/css/page-flows.fba8e213.css" rel="preload"/><link as="script" href="https://assets.habr.com/habr-web/js/page-flows.a3016599.js" rel="preload"/>
# <link href="https://assets.habr.com/habr-web/css/chunk-vendors.db52f5c6.css" rel="stylesheet"/><link href="https://assets.habr.com/habr-web/css/app.ac61f8eb.css" rel="stylesheet"/><link href="https://assets.habr.com/habr-web/css/page-flows.fba8e213.css" rel="stylesheet"/>
# <script>window.i18nFetch = new Promise((res, rej) => {
#           const xhr = new XMLHttpRequest();
#           xhr.open('GET', '/js/i18n/ru-compiled.07ab3411a33038d0c6f862dbea0a2c45.json');
#           xhr.responseType = 'json';
#           xhr.onload = function(e) {
#             if (this.status === 200) {
#               res({ru: xhr.response});
#             } else {
#               rej(e);
#             }
#           };
#           xhr.send();
#         });</script>
# <script data-vmid="checkad" data-vue-meta="ssr" onload="window['zhY4i4nJ9K'] = true" src="/js/ads.js"></script>
# <script async="" src="//www.googletagservices.com/tag/js/gpt.js"></script>
# <style>.grecaptcha-badge{visibility: hidden;}</style>
# <meta content="2.44.0" name="habr-version"/>
# <meta content="/img/habr_en.png" data-vmid="image:itemprop" data-vue-meta="ssr" itemprop="image"/><meta content="/img/habr_en.png" data-vmid="og:image" data-vue-meta="ssr" property="og:image"/><meta content="/img/habr_en.png" data-vmid="aiturec:image" data-vue-meta="ssr" property="aiturec:image"/><meta content="/img/habr_en.png" data-vmid="twitter:image" data-vue-meta="ssr" name="twitter:image"/><meta content="/img/habr_en.png" data-vmid="vk:image" data-vue-meta="ssr" property="vk:image"/><meta content="444736788986613" data-vue-meta="ssr" property="fb:app_id"/><meta content="472597926099084" data-vue-meta="ssr" property="fb:pages"/><meta content="summary_large_image" data-vue-meta="ssr" name="twitter:card"/><meta content="@habr_eng" data-vue-meta="ssr" name="twitter:site"/><meta content="ru_RU" data-vmid="og:locale" data-vue-meta="ssr" property="og:locale"/><meta content="website" data-vmid="og:type" data-vue-meta="ssr" property="og:type"/><meta content="Хабр — крупнейший в Европе ресурс для IT-специалистов. Сюда приходят обсудить новости индустрии и поделиться опытом." data-vmid="description" data-vue-meta="ssr" name="description"/>
# <link data-vmid="image:href" data-vue-meta="ssr" href="/img/habr_en.png" image_src="image"/><link data-vmid="canonical" data-vue-meta="ssr" href="https://habr.com/ru/all/" rel="canonical"/><link data-vmid="hreflang" data-vue-meta="ssr" href="https://habr.com/ru/all/" hreflang="ru" rel="alternate"/><link data-vmid="hreflang" data-vue-meta="ssr" href="https://habr.com/en/all/" hreflang="en" rel="alternate"/><link data-vue-meta="ssr" href="https://habr.com/ru/rss/all/all/?fl=ru" name="rss" rel="alternate" title="Все публикации подряд" type="application/rss+xml"/>
# <meta content="#303b44" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="#629FBC" name="msapplication-TileColor"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <link href="https://assets.habr.com/habr-web/img/favicons/favicon-16.png" rel="shortcut icon" sizes="16x16" type="image/png"/>
# <link href="https://assets.habr.com/habr-web/img/favicons/favicon-32.png" rel="shortcut icon" sizes="32x32" type="image/png"/>
# <link href="https://assets.habr.com/habr-web/img/favicons/apple-touch-icon-76.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/>
# <link href="https://assets.habr.com/habr-web/img/favicons/apple-touch-icon-120.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/>
# <link href="https://assets.habr.com/habr-web/img/favicons/apple-touch-icon-152.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/>
# <link href="https://assets.habr.com/habr-web/img/favicons/apple-touch-icon-180.png" rel="apple-touch-icon" sizes="180x180" type="image/png"/>
# <link href="https://assets.habr.com/habr-web/img/favicons/apple-touch-icon-256.png" rel="apple-touch-icon" sizes="256x256" type="image/png"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1136x640.png" media="screen and (device-width: 320px) and (device-height: 568px) and (-webkit-device-pixel-ratio: 2) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2436x1125.png" media="screen and (device-width: 375px) and (device-height: 812px) and (-webkit-device-pixel-ratio: 3) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1792x828.png" media="screen and (device-width: 414px) and (device-height: 896px) and (-webkit-device-pixel-ratio: 2) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_828x1792.png" media="screen and (device-width: 414px) and (device-height: 896px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1334x750.png" media="screen and (device-width: 375px) and (device-height: 667px) and (-webkit-device-pixel-ratio: 2) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1242x2668.png" media="screen and (device-width: 414px) and (device-height: 896px) and (-webkit-device-pixel-ratio: 3) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2208x1242.png" media="screen and (device-width: 414px) and (device-height: 736px) and (-webkit-device-pixel-ratio: 3) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1125x2436.png" media="screen and (device-width: 375px) and (device-height: 812px) and (-webkit-device-pixel-ratio: 3) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1242x2208.png" media="screen and (device-width: 414px) and (device-height: 736px) and (-webkit-device-pixel-ratio: 3) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2732x2048.png" media="screen and (device-width: 1024px) and (device-height: 1366px) and (-webkit-device-pixel-ratio: 2) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2688x1242.png" media="screen and (device-width: 414px) and (device-height: 896px) and (-webkit-device-pixel-ratio: 3) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2224x1668.png" media="screen and (device-width: 834px) and (device-height: 1112px) and (-webkit-device-pixel-ratio: 2) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_750x1334.png" media="screen and (device-width: 375px) and (device-height: 667px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2048x2732.png" media="screen and (device-width: 1024px) and (device-height: 1366px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2388x1668.png" media="screen and (device-width: 834px) and (device-height: 1194px) and (-webkit-device-pixel-ratio: 2) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1668x2224.png" media="screen and (device-width: 834px) and (device-height: 1112px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_640x1136.png" media="screen and (device-width: 320px) and (device-height: 568px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1668x2388.png" media="screen and (device-width: 834px) and (device-height: 1194px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2048x1536.png" media="screen and (device-width: 768px) and (device-height: 1024px) and (-webkit-device-pixel-ratio: 2) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1536x2048.png" media="screen and (device-width: 768px) and (device-height: 1024px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link color="#77a2b6" href="https://assets.habr.com/habr-web/img/favicons/apple-touch-icon-120.svg" rel="mask-icon"/>
# <link crossorigin="use-credentials" href="/manifest.webmanifest" rel="manifest"/>
# </head>
# <body>
# <div data-async-called="true" data-server-rendered="true" id="app"><div class="tm-layout__wrapper"><!-- --><div></div><!-- --><header class="tm-header"><div class="tm-page-width"><div class="tm-header__container"><!-- --><span class="tm-header__logo-wrap"><a class="tm-header__logo tm-header__logo_ru" href="/ru/"><svg class="tm-svg-img tm-header__icon" height="16" width="16"><title>Хабр</title><use xlink:href="/img/habr-logo-ru.svg#logo"></use></svg></a><span class="tm-header__beta-sign" style="display:none;">β</span></span><div class="tm-dropdown tm-header__projects"><div class="tm-dropdown__head"><button class="tm-header__dropdown-toggle"><svg class="tm-svg-img tm-header__icon tm-header__icon_dropdown" height="16" width="16"><title>Открыть список</title><use xlink:href="/img/megazord-v24.cee85629.svg#arrow-down"></use></svg></button></div><!-- --></div><a class="tm-header__become-author-btn" href="/ru/sandbox/start/">
#               Как стать автором
#             </a><div class="tm-feature tm-header__feature tm-feature_variant-inline"><!-- --></div><!-- --><!-- --></div></div></header><div class="tm-layout"><div class="tm-page-progress-bar"></div><div class="tm-base-layout__header tm-base-layout__header_is-sticky" data-menu-sticky="true"><div class="tm-page-width"><div class="tm-base-layout__header-wrapper"><div class="tm-main-menu"><div class="tm-main-menu__section"><nav class="tm-main-menu__section-content"><!-- --><a aria-current="page" class="tm-main-menu__item router-link-exact-active tm-main-menu__item_active" href="/ru/all/">
#         Все потоки
#       </a><a class="tm-main-menu__item" href="/ru/flows/develop/">
#           Разработка
#         </a><a class="tm-main-menu__item" href="/ru/flows/admin/">
#           Администрирование
#         </a><a class="tm-main-menu__item" href="/ru/flows/design/">
#           Дизайн
#         </a><a class="tm-main-menu__item" href="/ru/flows/management/">
#           Менеджмент
#         </a><a class="tm-main-menu__item" href="/ru/flows/marketing/">
#           Маркетинг
#         </a><a class="tm-main-menu__item" href="/ru/flows/popsci/">
#           Научпоп
#         </a></nav></div></div><div class="tm-header-user-menu tm-base-layout__user-menu"><a class="tm-header-user-menu__item tm-header-user-menu__search" href="/ru/search/"><svg class="tm-svg-img tm-header-user-menu__icon tm-header-user-menu__icon_search tm-header-user-menu__icon_dark" height="24" width="24"><title>Поиск</title><use xlink:href="/img/megazord-v24.cee85629.svg#search"></use></svg></a><!-- --><!-- --><!-- --><div class="tm-header-user-menu__item tm-header-user-menu__user_desktop"><div class="tm-dropdown"><div class="tm-dropdown__head"><svg class="tm-svg-img tm-header-user-menu__icon" data-test-id="menu-toggle-guest" height="24" width="24"><title>Профиль</title><use xlink:href="/img/megazord-v24.cee85629.svg#header-user"></use></svg><!-- --></div><!-- --></div><!-- --></div><!-- --></div></div></div></div><!-- --><div class="tm-page-width"></div><main class="tm-layout__container"><div class="tm-page"><div class="tm-page-width"><!-- --><div class="tm-page__wrapper"><div class="tm-page__main tm-page__main_has-sidebar"><div class="pull-down"><div class="pull-down__header" style="height:0px;"><div class="pull-down__content" style="bottom:10px;"><svg class="tm-svg-img pull-down__arrow" height="24" width="24"><title>Обновить</title><use xlink:href="/img/megazord-v24.cee85629.svg#pull-arrow"></use></svg></div></div><div class="tm-page__top"><div class="tm-section-name"><h1 class="tm-section-name__text">
#     Все потоки
#   </h1></div><div class="tm-tabs tm-tabs_page-header"><div class="tm-tabs__scroll-area"><span class="tm-tabs__tab-item"><a aria-current="page" class="tm-tabs__tab-link router-link-exact-active tm-tabs__tab-link_active" href="/ru/all/">
#         Статьи
#         <!-- --></a></span><span class="tm-tabs__tab-item"><a class="tm-tabs__tab-link" href="/ru/news/">
#         Новости
#         <!-- --></a></span><span class="tm-tabs__tab-item"><a class="tm-tabs__tab-link" href="/ru/hubs/">
#         Хабы
#         <!-- --></a></span><span class="tm-tabs__tab-item"><a class="tm-tabs__tab-link" href="/ru/users/">
#         Авторы
#         <!-- --></a></span><span class="tm-tabs__tab-item"><a class="tm-tabs__tab-link" href="/ru/companies/">
#         Компании
#         <!-- --></a></span></div><!-- --></div><div class="tm-navigation-filter"><div class="tm-navigation-filters"><div class="tm-navigation-filters__wrapper"><button class="tm-navigation-filters__button">
#       Все подряд
#       <svg class="tm-svg-img icon_dropdown-arrow" height="16" width="16"><title>Открыть список</title><use xlink:href="/img/megazord-v24.cee85629.svg#arrow-down"></use></svg></button><button class="tm-rss-button tm-rss-button_default"><span class="tm-svg-icon__wrapper tm-rss-button__icon"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Скопировать ссылку на RSS</title><use xlink:href="/img/megazord-v24.cee85629.svg#rss"></use></svg></span></button></div><div class="tm-navigation-filters__options"><div class="tm-navigation-filters__list-label">
#       Сначала показывать
#     </div><ul class="tm-navigation-filters__list"><li class="tm-navigation-filters__option tm-navigation-filters__option_active">
#         Новые
#       </li><li class="tm-navigation-filters__option">
#         Лучшие
#       </li></ul><div class="tm-navigation-filters__list-label">
#       Порог рейтинга
#     </div><ul class="tm-navigation-filters__list"><li class="tm-navigation-filters__option tm-navigation-filters__option_active">
#         Все
#       </li><li class="tm-navigation-filters__option">
#         ≥0
#       </li><li class="tm-navigation-filters__option">
#         ≥10
#       </li><li class="tm-navigation-filters__option">
#         ≥25
#       </li><li class="tm-navigation-filters__option">
#         ≥50
#       </li><li class="tm-navigation-filters__option">
#         ≥100
#       </li></ul><button class="tm-navigation-filters__apply btn btn_solid btn_small" type="button">
#       Применить
#     </button></div></div></div><!-- --></div><div class="tm-articles-subpage" data-async-called="true"><!-- --><div><div class="tm-articles-list"><!-- --><article class="tm-articles-list__item" data-navigatable="" id="573776" tabindex="0"><div class="tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/wlkr/" title="wlkr"><div class="tm-entity-image"><svg class="tm-svg-img tm-image-placeholder tm-image-placeholder_blue" height="24" width="24"><!-- --><use xlink:href="/img/megazord-v24.cee85629.svg#placeholder-user"></use></svg></div></a><span class="tm-user-info__user"><a class="tm-user-info__username" href="/ru/users/wlkr/">
#       wlkr
#     </a></span></span><span class="tm-article-snippet__datetime-published"><time datetime="2021-08-19T15:07:46.000Z" title="2021-08-19, 18:07">сегодня в 18:07</time></span></div><!-- --></div><h2 class="tm-article-snippet__title tm-article-snippet__title_h2"><a class="tm-article-snippet__title-link" data-article-link="" href="/ru/post/573776/"><span>Домик в деревне и цифровые модели рельефа</span></a></h2><div class="tm-article-snippet__hubs"><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/geo/"><span>Геоинформационные сервисы</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/opendata/"><span>Открытые данные</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/data_visualization/"><span>Визуализация данных</span><!-- --></a></span></div><div class="tm-article-snippet__labels"><!-- --></div><!-- --><div class="tm-article-body tm-article-snippet__lead">
# <div class="tm-article-snippet__cover tm-article-snippet__cover_cover"><img class="tm-article-snippet__lead-image" src="https://habrastorage.org/getpro/habr/upload_files/cc1/ad8/195/cc1ad81956c536ce435766a6c4854b3c.png" style="object-position:0% 0%;"/></div><div class="article-formatted-body article-formatted-body_version-2"><p>Сбылась мечта вашего детства—вы присмотрели себе домик в деревне​! Домик в отличном состоянии, из окна прекрасный вид, под самым окном тихо журчит речка Переплюйка, жизнь прекрасна! Вы совсем было собрались его купить, но вдруг достали телефон и зачем-то решили почитать новости. А там—изменения климата, очередное наводнение неважно где, с разрушениями и жертвами. И вдруг вы с беспокойством смотрите на речку Переплюйку прямо перед вами, и думаете, а не превратится ли она в случае чего в бурный поток, смывающий всё нажитое непосильным трудом? Давайте посмотрим, чем технологии ГИС (геоинформационных систем) могут вам помочь, и почему свободный доступ граждан к географическим данным полезен для принятия решений.</p></div><a class="tm-article-snippet__readmore" href="/ru/post/573776/"><span>Читать далее</span></a></div></div><div class="tm-data-icons"><!-- --><div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon_small" height="16" width="16"><title>Рейтинг</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-rating"></use></svg><span class="tm-votes-meter__value tm-votes-meter__value_small">0</span></div><span class="tm-icon-counter tm-data-icons__item" title="Количество просмотров"><svg class="tm-svg-img tm-icon-counter__icon" height="16" width="16"><title>Просмотры</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-views"></use></svg><span class="tm-icon-counter__value">1</span></span><button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon" title="Добавить в закладки"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Добавить в закладки</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-favorite"></use></svg></span><span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#     0
#   </span></button><div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/post/573776/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="16" width="16"><title>Комментарии</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-comments"></use></svg><span class="tm-article-comments-counter-link__value">
#       0
#     </span></a><!-- --></div><!-- --><div class="v-portal" style="display:none;"></div></div></article><div class="tm-articles-list__after-article"><section class="tm-block tm-block_spacing-bottom" data-navigatable="" data-test-id="news_block" id="news_block_1" tabindex="0"><header class="tm-block__header tm-block__header_variant-borderless"><h2 class="tm-block__title">Новости</h2><!-- --></header><div class="tm-block__body"><ul class="tm-news-block__items"><li class="tm-news-block__item" data-test-id="news_block_item_loading"><div class="news-block-item-placeholder"><div class="news-block-item-placeholder__header" style="width:223px;"></div><div class="news-block-item-placeholder__meta" style="width:258px;"></div></div></li><li class="tm-news-block__item" data-test-id="news_block_item_loading"><div class="news-block-item-placeholder"><div class="news-block-item-placeholder__header" style="width:278px;"></div><div class="news-block-item-placeholder__meta" style="width:254px;"></div></div></li><li class="tm-news-block__item" data-test-id="news_block_item_loading"><div class="news-block-item-placeholder"><div class="news-block-item-placeholder__header" style="width:146px;"></div><div class="news-block-item-placeholder__meta" style="width:242px;"></div></div></li><li class="tm-news-block__item" data-test-id="news_block_item_loading"><div class="news-block-item-placeholder"><div class="news-block-item-placeholder__header" style="width:284px;"></div><div class="news-block-item-placeholder__meta" style="width:259px;"></div></div></li><li class="tm-news-block__item" data-test-id="news_block_item_loading"><div class="news-block-item-placeholder"><div class="news-block-item-placeholder__header" style="width:206px;"></div><div class="news-block-item-placeholder__meta" style="width:269px;"></div></div></li></ul><span class="tm-news-block__all">
#     Показать еще
#   </span></div><!-- --></section></div><!-- --><article class="tm-articles-list__item" data-navigatable="" id="573774" tabindex="0"><div class="tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/pureacetone/" title="pureacetone"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="24" loading="lazy" src="//habrastorage.org/r/w32/getpro/habr/avatars/053/a91/47d/053a9147d1635e229765d7f57af3db63.png" width="24"/></div></a><span class="tm-user-info__user"><a class="tm-user-info__username" href="/ru/users/pureacetone/">
#       pureacetone
#     </a></span></span><span class="tm-article-snippet__datetime-published"><time datetime="2021-08-19T15:03:34.000Z" title="2021-08-19, 18:03">сегодня в 18:03</time></span></div><!-- --></div><h2 class="tm-article-snippet__title tm-article-snippet__title_h2"><a class="tm-article-snippet__title-link" data-article-link="" href="/ru/company/itsoft/blog/573774/"><span>GOSTCoin. История первой криптовалюты в I2P</span></a></h2><div class="tm-article-snippet__hubs"><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/company/itsoft/blog/"><span>Блог компании ITSOFT</span><!-- --></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/crypto/"><span>Криптография</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/i2p/"><span>I2P</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/cryptocurrency/"><span>Криптовалюты</span><!-- --></a></span></div><div class="tm-article-snippet__labels"><!-- --></div><!-- --><div class="tm-article-body tm-article-snippet__lead">
# <div class="tm-article-snippet__cover tm-article-snippet__cover_cover"><img class="tm-article-snippet__lead-image" src="https://habrastorage.org/getpro/habr/upload_files/fbe/a52/692/fbea526927d0b07126d9fcfa57ce34ca.jpg" style="object-position:0% 0%;"/></div><div class="article-formatted-body article-formatted-body_version-2"><p>Эта статья посвящена криптовалюте, в основе которой лежит стандартизированная российская криптография. В отличие от других ноу-неймов, ее разработала команда с именем, а сама валюта не рекламировалась в инстаграм-профилях с миллионной аудиторией. Из материала вы узнаете историю первой в мире криптомонеты, которая стала полностью адаптирована для работы через <a href="https://habr.com/ru/post/552072/">I2P</a> без единой нужды обращаться в обычный интернет, где запросы подвержены перехвату, анализу и блокировкам.</p></div><a class="tm-article-snippet__readmore" href="/ru/company/itsoft/blog/573774/"><span>Читать далее</span></a></div></div><div class="tm-data-icons"><!-- --><div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon_small" height="16" width="16"><title>Рейтинг</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-rating"></use></svg><span class="tm-votes-meter__value tm-votes-meter__value_small">0</span></div><span class="tm-icon-counter tm-data-icons__item" title="Количество просмотров"><svg class="tm-svg-img tm-icon-counter__icon" height="16" width="16"><title>Просмотры</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-views"></use></svg><span class="tm-icon-counter__value">10</span></span><button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon" title="Добавить в закладки"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Добавить в закладки</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-favorite"></use></svg></span><span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#     0
#   </span></button><div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/company/itsoft/blog/573774/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="16" width="16"><title>Комментарии</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-comments"></use></svg><span class="tm-article-comments-counter-link__value">
#       0
#     </span></a><!-- --></div><!-- --><div class="v-portal" style="display:none;"></div></div></article><div class="tm-articles-list__after-article"><!-- --></div><!-- --><article class="tm-articles-list__item" data-navigatable="" id="573772" tabindex="0"><div class="tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/hedgehog_on_rainbow/" title="hedgehog_on_rainbow"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="24" loading="lazy" src="//habrastorage.org/r/w32/getpro/habr/avatars/5f2/458/0d5/5f24580d57ae3d6961d9da7f5372641a.png" width="24"/></div></a><span class="tm-user-info__user"><a class="tm-user-info__username" href="/ru/users/hedgehog_on_rainbow/">
#       hedgehog_on_rainbow
#     </a></span></span><span class="tm-article-snippet__datetime-published"><time datetime="2021-08-19T14:52:40.000Z" title="2021-08-19, 17:52">сегодня в 17:52</time></span></div><!-- --></div><h2 class="tm-article-snippet__title tm-article-snippet__title_h2"><a class="tm-article-snippet__title-link" data-article-link="" href="/ru/company/exness/blog/573772/"><span>MasterCard откажется от магнитных полос на картах</span></a></h2><div class="tm-article-snippet__hubs"><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/company/exness/blog/"><span>Блог компании Exness</span><!-- --></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/infosecurity/"><span>Информационная безопасность</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/finance/"><span>Финансы в IT</span><!-- --></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/futurenow/"><span>Будущее здесь</span><!-- --></a></span></div><div class="tm-article-snippet__labels"><!-- --></div><!-- --><div class="tm-article-body tm-article-snippet__lead">
# <div class="tm-article-snippet__cover tm-article-snippet__cover_cover"><img class="tm-article-snippet__lead-image" src="https://habrastorage.org/getpro/habr/upload_files/e80/006/3e7/e800063e7b2ac5930d064fe2012d07b4.jpeg" style="object-position:0% 0%;"/></div><div class="article-formatted-body article-formatted-body_version-2"><p>Уходит целая эпоха: Корпорация MasterCard пообещала <a href="https://www.mastercard.com/news/perspectives/2021/magnetic-stripe/"><u>отказаться</u></a> от магнитной полосы на картах к 2033 году и перейти к таким безопасным альтернативам как чипы и бесконтактные платежи. </p><p>А мы решили вспомнить о том, как все начиналось, и поразмышлять над тем, что ждет нас после отказа от магнитных полос. </p></div><a class="tm-article-snippet__readmore" href="/ru/company/exness/blog/573772/"><span>Читать далее</span></a></div></div><div class="tm-data-icons"><!-- --><div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon_small" height="16" width="16"><title>Всего голосов 4: ↑4 и ↓0</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-rating"></use></svg><span class="tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_small" title="Всего голосов 4: ↑4 и ↓0">+4</span></div><span class="tm-icon-counter tm-data-icons__item" title="Количество просмотров"><svg class="tm-svg-img tm-icon-counter__icon" height="16" width="16"><title>Просмотры</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-views"></use></svg><span class="tm-icon-counter__value">279</span></span><button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon" title="Добавить в закладки"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Добавить в закладки</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-favorite"></use></svg></span><span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#     0
#   </span></button><div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/company/exness/blog/573772/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="16" width="16"><title>Комментарии</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-comments"></use></svg><span class="tm-article-comments-counter-link__value">
#       1
#     </span></a><!-- --></div><!-- --><div class="v-portal" style="display:none;"></div></div></article><div class="tm-articles-list__after-article"><!-- --></div><!-- --><article class="tm-articles-list__item" data-navigatable="" id="573470" tabindex="0"><div class="tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/gayka_m8/" title="gayka_m8"><div class="tm-entity-image"><svg class="tm-svg-img tm-image-placeholder tm-image-placeholder_pink" height="24" width="24"><!-- --><use xlink:href="/img/megazord-v24.cee85629.svg#placeholder-user"></use></svg></div></a><span class="tm-user-info__user"><a class="tm-user-info__username" href="/ru/users/gayka_m8/">
#       gayka_m8
#     </a></span></span><span class="tm-article-snippet__datetime-published"><time datetime="2021-08-19T14:13:01.000Z" title="2021-08-19, 17:13">сегодня в 17:13</time></span></div><!-- --></div><h2 class="tm-article-snippet__title tm-article-snippet__title_h2"><a class="tm-article-snippet__title-link" data-article-link="" href="/ru/company/dododev/blog/573470/"><span>Молодые не идут в .NET. Правда или нет?</span></a></h2><div class="tm-article-snippet__hubs"><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/company/dododev/blog/"><span>Блог компании Dodo Engineering</span><!-- --></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/webdev/"><span>Разработка веб-сайтов</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/net/"><span>.NET</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/csharp/"><span>C#</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/career/"><span>Карьера в IT-индустрии</span><!-- --></a></span></div><div class="tm-article-snippet__labels"><!-- --></div><!-- --><div class="tm-article-body tm-article-snippet__lead">
# <div class="tm-article-snippet__cover tm-article-snippet__cover_cover"><img class="tm-article-snippet__lead-image" src="https://habrastorage.org/getpro/habr/upload_files/db0/72c/a5b/db072ca5b9aee6faf3b07d37d0eec777.png" style="object-position:0% 0%;"/></div><div class="article-formatted-body article-formatted-body_version-2"><p>Как-то раз наши разработчики тёрли за что-то важное у кофемашины и между делом стебались, что им скоро придётся уйти из .NET, потому что язык вымирает. Шутки шутками, но мысль застряла в голове и не отпускала.</p><p>Чтобы прояснить ситуацию, мы заглянули в DotNet-сообщество, сходили  к ребятам из Microsoft, Райффайзенбанка, Контура, CUSTIS и задали несколько вопросов. Вы тоже возьмите чашечку кофе, устройтесь поудобнее, поразмышляйте о будущем .NET и поделитесь своими мыслями в комментариях.</p></div><a class="tm-article-snippet__readmore" href="/ru/company/dododev/blog/573470/"><span>Читать далее</span></a></div></div><div class="tm-data-icons"><!-- --><div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon_small" height="16" width="16"><title>Всего голосов 10: ↑9 и ↓1</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-rating"></use></svg><span class="tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_small" title="Всего голосов 10: ↑9 и ↓1">+8</span></div><span class="tm-icon-counter tm-data-icons__item" title="Количество просмотров"><svg class="tm-svg-img tm-icon-counter__icon" height="16" width="16"><title>Просмотры</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-views"></use></svg><span class="tm-icon-counter__value">1.4K</span></span><button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon" title="Добавить в закладки"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Добавить в закладки</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-favorite"></use></svg></span><span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#     3
#   </span></button><div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/company/dododev/blog/573470/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="16" width="16"><title>Комментарии</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-comments"></use></svg><span class="tm-article-comments-counter-link__value">
#       5
#     </span></a><!-- --></div><!-- --><div class="v-portal" style="display:none;"></div></div></article><div class="tm-articles-list__after-article"><div class="tm-article-feed-blocks"><!-- --></div></div><!-- --><article class="tm-articles-list__item" data-navigatable="" id="573766" tabindex="0"><div class="tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/PPR/" title="PPR"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="24" loading="lazy" src="//habrastorage.org/r/w32/getpro/habr/avatars/474/1fb/0f8/4741fb0f8dabdbe1480fbc5ce537d15b.png" width="24"/></div></a><span class="tm-user-info__user"><a class="tm-user-info__username" href="/ru/users/PPR/">
#       PPR
#     </a></span></span><span class="tm-article-snippet__datetime-published"><time datetime="2021-08-19T13:56:20.000Z" title="2021-08-19, 16:56">сегодня в 16:56</time></span></div><!-- --></div><h2 class="tm-article-snippet__title tm-article-snippet__title_h2"><a class="tm-article-snippet__title-link" data-article-link="" href="/ru/post/573766/"><span>Обдурить Шаи-Хулуда</span></a></h2><div class="tm-article-snippet__hubs"><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/infosecurity/"><span>Информационная безопасность</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/sys_admin/"><span>Системное администрирование</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/bigdata/"><span>Big Data</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span></div><div class="tm-article-snippet__labels"><!-- --></div><!-- --><div class="tm-article-body tm-article-snippet__lead">
# <div class="tm-article-snippet__cover tm-article-snippet__cover_cover"><img class="tm-article-snippet__lead-image" src="https://habrastorage.org/getpro/habr/upload_files/6e5/ee3/2d4/6e5ee32d47601f9c59c671c6e8e3672c.jpg" style="object-position:0% 0%;"/></div><div class="article-formatted-body article-formatted-body_version-2"><p>Привет, Хабр! </p><p>Сегодня поговорим о «больших данных» в кибербезопасности, а точнее, о том насколько легко - или сложно - обойти защиту, использующую Big Data. Иначе говоря, как надурить и объегорить передовые системы обнаружения угроз, мимо всевидящего ока которых, как утверждают маркетологи, лишний байт не проскочит.</p><p>О чём, собственно говоря, речь? О системах идентификации кибератак, использующих анализ «больших данных» в качестве одного из основных инструментов выявления подозрительной активности, - системы SIEM и XDR. Такие платформы в принципе ориентированы на средний и крупный бизнес, крупные сети и облачную инфраструктуру, в которой происходят миллионы событий ежечасно. Естественно, и речи не может идти о том, чтобы анализировать их «вручную», всё это осуществляется с интенсивным использованием технических средств, хотя наличие квалифицированных специалистов - и в области «больших данных», и в области кибербезопасности, - абсолютно необходимая составляющая.</p><p>Что делают такие системы? Позволяют идентифицировать в огромных (Big, очень Big) массивах структурированных и неструктурированных данных признаки несанкционированной активности. Иначе говоря, кибератак. Учитывая, что в средних размеров сети, насчитывающей 20 тысяч конечных точек, за сутки транслируется около 50 терабайт данных, задача «прошерстить» всё это становится очень неординарной.</p><p>Для этого существуют множественные алгоритмы. Основным критерием качества платформ обнаружения угроз - в частности, XDR, является точность обнаружения аномалий в системах, которые они защищают. <strong>XDR</strong>-решения, как правило, включают в себя и SIEM-платформы, отвечающие за сбор и обработку событий, и <strong>EDR</strong> - обнаружение и реагирование на аномалии, и <strong>UBA/UEBA</strong> - системы, которые собирают (большие) массивы данных о действиях пользователей и/или конечных точек, серверов и сетевого оборудования, а затем с помощью алгоритмов машинного обучения выстраивают модели поведения и пытаются выявить отклонения от них. </p></div><a class="tm-article-snippet__readmore" href="/ru/post/573766/"><span>Читать далее</span></a></div></div><div class="tm-data-icons"><!-- --><div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon_small" height="16" width="16"><title>Всего голосов 1: ↑1 и ↓0</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-rating"></use></svg><span class="tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_small" title="Всего голосов 1: ↑1 и ↓0">+1</span></div><span class="tm-icon-counter tm-data-icons__item" title="Количество просмотров"><svg class="tm-svg-img tm-icon-counter__icon" height="16" width="16"><title>Просмотры</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-views"></use></svg><span class="tm-icon-counter__value">339</span></span><button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon" title="Добавить в закладки"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Добавить в закладки</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-favorite"></use></svg></span><span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#     1
#   </span></button><div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/post/573766/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="16" width="16"><title>Комментарии</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-comments"></use></svg><span class="tm-article-comments-counter-link__value">
#       0
#     </span></a><!-- --></div><!-- --><div class="v-portal" style="display:none;"></div></div></article><div class="tm-articles-list__after-article"><!-- --></div><!-- --><article class="tm-articles-list__item" data-navigatable="" id="569270" tabindex="0"><div class="tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/lelyakuznetsova/" title="lelyakuznetsova"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="24" loading="lazy" src="//habrastorage.org/r/w32/getpro/habr/avatars/fc3/c4a/165/fc3c4a1651f7c92e5166a1883b1cc5bb.jpg" width="24"/></div></a><span class="tm-user-info__user"><a class="tm-user-info__username" href="/ru/users/lelyakuznetsova/">
#       lelyakuznetsova
#     </a></span></span><span class="tm-article-snippet__datetime-published"><time datetime="2021-08-19T13:55:31.000Z" title="2021-08-19, 16:55">сегодня в 16:55</time></span></div><!-- --></div><h2 class="tm-article-snippet__title tm-article-snippet__title_h2"><a class="tm-article-snippet__title-link" data-article-link="" href="/ru/company/jugru/blog/569270/"><span>Эффективный поиск XSS-уязвимостей</span></a></h2><div class="tm-article-snippet__hubs"><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/company/jugru/blog/"><span>Блог компании JUG Ru Group</span><!-- --></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/infosecurity/"><span>Информационная безопасность</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/javascript/"><span>JavaScript</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/web_testing/"><span>Тестирование веб-сервисов</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/tech_events/"><span>Конференции</span><!-- --></a></span></div><div class="tm-article-snippet__labels"><!-- --></div><!-- --><div class="tm-article-body tm-article-snippet__lead">
# <!-- --><div class="article-formatted-body article-formatted-body_version-1"><p><img src="https://habrastorage.org/webt/pe/ed/5c/peed5cpoi-4fqgjnbv4l3faam0k.jpeg"/></p><br/>
# <p>Про XSS-уязвимости известно давным-давно — казалось бы, нужен ли миру ещё один материал о них? Но когда <strong>Иван Румак</strong>, занимающийся тестированием безопасности, поделился методологией их поиска на нашей конференции <strong><a href="https://heisenbug-moscow.ru/?utm_source=habr&amp;utm_medium=569270" rel="nofollow noopener noreferrer">Heisenbug</a></strong>, реакция зрителей оказалась очень положительной. </p><br/>
# ...
#       Все компании
#     </a></footer></section><!-- --></div></div></div></div></div></div></main><!-- --></div><div class="tm-footer-menu"><div class="tm-page-width"><div class="tm-footer-menu__container"><div class="tm-footer-menu__block"><h3 class="tm-footer-menu__block-title">
#           Ваш аккаунт
#         </h3><div class="tm-footer-menu__block-content"><ul class="tm-footer-menu__list"><li class="tm-footer-menu__list-item"><a href="/kek/v1/auth/habrahabr/?back=/ru/all/&amp;hl=ru" target="_self">
#                 Войти
#               </a></li><li class="tm-footer-menu__list-item"><a href="/kek/v1/auth/habrahabr-register/?back=/ru/all/&amp;hl=ru" target="_self">
#                 Регистрация
#               </a></li></ul></div></div><div class="tm-footer-menu__block"><h3 class="tm-footer-menu__block-title">
#           Разделы
#         </h3><div class="tm-footer-menu__block-content"><ul class="tm-footer-menu__list"><li class="tm-footer-menu__list-item"><a class="footer-menu__item-link router-link-active" href="/ru/">
#                 Публикации
#               </a></li><li class="tm-footer-menu__list-item"><a class="footer-menu__item-link" href="/ru/news/">
#                 Новости
#               </a></li><li class="tm-footer-menu__list-item"><a class="footer-menu__item-link" href="/ru/hubs/">
#                 Хабы
#               </a></li><li class="tm-footer-menu__list-item"><a class="footer-menu__item-link" href="/ru/companies/">
#                 Компании
#               </a></li><li class="tm-footer-menu__list-item"><a class="footer-menu__item-link" href="/ru/users/">
#                 Авторы
#               </a></li><li class="tm-footer-menu__list-item"><a class="footer-menu__item-link" href="/ru/sandbox/">
#                 Песочница
#               </a></li></ul></div></div><div class="tm-footer-menu__block"><h3 class="tm-footer-menu__block-title">
#           Информация
#         </h3><div class="tm-footer-menu__block-content"><ul class="tm-footer-menu__list"><li class="tm-footer-menu__list-item"><a class="footer-menu__item-link" href="/ru/docs/help/">
#                 Устройство сайта
#               </a></li><li class="tm-footer-menu__list-item"><a class="footer-menu__item-link" href="/ru/docs/authors/codex/">
#                 Для авторов
#               </a></li><li class="tm-footer-menu__list-item"><a class="footer-menu__item-link" href="/ru/docs/companies/corpblogs/">
#                 Для компаний
#               </a></li><li class="tm-footer-menu__list-item"><a class="footer-menu__item-link" href="/ru/docs/docs/transparency/">
#                 Документы
#               </a></li><li class="tm-footer-menu__list-item"><a href="https://account.habr.com/info/agreement" target="_blank">
#                 Соглашение
#               </a></li><li class="tm-footer-menu__list-item"><a href="https://account.habr.com/info/confidential/" target="_blank">
#                 Конфиденциальность
#               </a></li></ul></div></div><div class="tm-footer-menu__block"><h3 class="tm-footer-menu__block-title">
#           Услуги
#         </h3><div class="tm-footer-menu__block-content"><ul class="tm-footer-menu__list"><li class="tm-footer-menu__list-item"><a href="https://docs.google.com/presentation/d/e/2PACX-1vQLwRfQmXibiUlWaRg-BAc38s7oM3lJiaPju7qmdJsp8ysIvZ_G-Npem0njJLMozE2bPHMpDqiI5hhy/pub?start=false&amp;loop=false&amp;delayms=60000&amp;slide=id.g91a03369cd_4_297" target="_blank">
#                 Реклама
#               </a></li><li class="tm-footer-menu__list-item"><a href="https://habrastorage.org/storage/stuff/habr/service_price.pdf" target="_blank">
#                 Тарифы
#               </a></li><li class="tm-footer-menu__list-item"><a href="https://docs.google.com/presentation/d/e/2PACX-1vQJJds8-Di7BQSP_guHxICN7woVYoN5NP_22ra-BIo4bqnTT9FR6fB-Ku2P0AoRpX0Ds-LRkDeAoD8F/pub?start=false&amp;loop=false&amp;delayms=60000" target="_blank">
#                 Контент
#               </a></li><li class="tm-footer-menu__list-item"><a href="https://tmtm.timepad.ru/" target="_blank">
#                 Семинары
#               </a></li><li class="tm-footer-menu__list-item"><a class="footer-menu__item-link" href="/ru/megaprojects/">
#                 Мегапроекты
#               </a></li></ul></div></div></div></div></div><div class="tm-footer"><div class="tm-page-width"><div class="tm-footer__container"><!-- --><div class="tm-footer__social"><a class="tm-svg-icon__wrapper tm-social-icons__icon" href="https://www.facebook.com/habrahabr.ru" rel="nofollow noopener noreferrer" target="_blank"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Facebook</title><use xlink:href="/img/social-icons-sprite.svg#social-logo-facebook"></use></svg></a><a class="tm-svg-icon__wrapper tm-social-icons__icon" href="https://twitter.com/habr_com" rel="nofollow noopener noreferrer" target="_blank"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Twitter</title><use xlink:href="/img/social-icons-sprite.svg#social-logo-twitter"></use></svg></a><a class="tm-svg-icon__wrapper tm-social-icons__icon" href="https://vk.com/habr" rel="nofollow noopener noreferrer" target="_blank"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>VK</title><use xlink:href="/img/social-icons-sprite.svg#social-logo-vkontakte"></use></svg></a><a class="tm-svg-icon__wrapper tm-social-icons__icon" href="https://telegram.me/habr_com" rel="nofollow noopener noreferrer" target="_blank"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Telegram</title><use xlink:href="/img/social-icons-sprite.svg#social-logo-telegram"></use></svg></a><a class="tm-svg-icon__wrapper tm-social-icons__icon" href="https://www.youtube.com/channel/UCd_sTwKqVrweTt4oAKY5y4w" rel="nofollow noopener noreferrer" target="_blank"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Youtube</title><use xlink:href="/img/social-icons-sprite.svg#social-logo-youtube"></use></svg></a><a class="tm-svg-icon__wrapper tm-social-icons__icon" href="https://zen.yandex.ru/habr" rel="nofollow noopener noreferrer" target="_blank"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Яндекс Дзен</title><use xlink:href="/img/social-icons-sprite.svg#social-logo-zen"></use></svg></a></div><div class="v-portal" style="display:none;"></div><button class="tm-footer__link"><!-- -->
#         Настройка языка
#       </button><a class="tm-footer__link" href="/ru/about">
#         О сайте
#       </a><a class="tm-footer__link" href="/ru/feedback/">
#         Техническая поддержка
#       </a><!-- --><a class="tm-footer__link" href="/berserk-mode-nope">
#         Вернуться на старую версию
#       </a><div class="tm-footer-copyright"><span class="tm-copyright"><span class="tm-copyright__years">© 2006–2021 </span><span class="tm-copyright__name">«<a class="tm-copyright__link" href="https://company.habr.com/" rel="noopener" target="_blank">Habr</a>»</span></span></div></div></div></div><!-- --><!-- --></div><div class="vue-portal-target"></div></div>
# <script>window.__INITIAL_STATE__={"adblock":{"hasAcceptableAdsFilter":false,"hasAdblock":false},"articlesList":{"articlesList":{"569270":{"id":"569270","timePublished":"2021-08-19T13:55:31+00:00","isCorporative":true,"lang":"ru","titleHtml":"Эффективный поиск XSS-уязвимостей","editorVersion":"1.0","postType":"article","postLabels":[],"author":{"id":"2476151","alias":"lelyakuznetsova","fullname":"Olga Kuznetsova","avatarUrl":"\u002F\u002Fhabrastorage.org\u002Fgetpro\u002Fhabr\u002Favatars\u002Ffc3\u002Fc4a\u002F165\u002Ffc3c4a1651f7c92e5166a1883b1cc5bb.jpg","speciality":"Редактор"},"statistics":{"commentsCount":3,"favoritesCount":8,"readingCount":300,"score":1,"votesCount":1},"hubs":[{"relatedData":null,"id":"18226","alias":"jugru","type":"corporative","title":"Блог компании JUG Ru Group","titleHtml":"Блог компании JUG Ru Group","isProfiled":false},{"relatedData":null,"id":"50","alias":"infosecurity","type":"collective","title":"Информационная безопасность","titleHtml":"Информационная безопасность","isProfiled":true},{"relatedData":null,"id":"357","alias":"javascript","type":"collective","title":"JavaScript","titleHtml":"JavaScript","isProfiled":true},{"relatedData":null,"id":"19279","alias":"web_testing","type":"collective","title":"Тестирование веб-сервисов","titleHtml":"Тестирование веб-сервисов","isProfiled":true},{"relatedData":null,"id":"20754","alias":"tech_events","type":"collective","title":"Конференции","titleHtml":"Конференции","isProfiled":false}],"flows":[{"id":"1","alias":"develop","title":"Разработка"},{"id":"4","alias":"marketing","title":"Маркетинг"}],"relatedData":null,"leadData":{"textHtml":"\u003Cp\u003E\u003Cimg src=\"https:\u002F\u002Fhabrastorage.org\u002Fwebt\u002Fpe\u002Fed\u002F5c\u002Fpeed5cpoi-4fqgjnbv4l3faam0k.jpeg\"\u003E\u003C\u002Fp\u003E\u003Cbr\u003E\r\n\u003Cp\u003EПро XSS-уязвимости известно давным-давно — казалось бы, нужен ли миру ещё один материал о них? Но когда \u003Cstrong\u003EИван Румак\u003C\u002Fstrong\u003E, занимающийся тестированием безопасности, поделился методологией их поиска на нашей конференции \u003Cstrong\u003E\u003Ca href=\"https:\u002F\u002Fheisenbug-moscow.ru\u002F?utm_source=habr&amp;utm_medium=569270\" rel=\"nofollow noopener noreferrer\"\u003EHeisenbug\u003C\u002Fa\u003E\u003C\u002Fstrong\u003E, реакция зрителей оказалась очень положительной. \u003C\u002Fp\u003E\u003Cbr\u003E\r\n\u003Cp\u003EИ спустя два года у этого доклада по-прежнему растут просмотры и лайки, это один из самых востребованных материалов Heisenbug. Поэтому теперь мы решили, что многим будет полезна текстовая версия, и сделали ее для Хабра.\u003C\u002Fp\u003E\u003Cbr\u003E\r\n\u003Cp\u003EПод катом — и текст, и видео. Далее повествование идет от лица Ивана.\u003C\u002Fp\u003E","imageUrl":null,"buttonTextHtml":"Читать дальше &rarr;","image":null},"status":"published","plannedPublishTime":null,"checked":null,"tags":[{"titleHtml":"xss уязвимость"},{"titleHtml":"xss vulnerability"},{"titleHtml":"иван румак"},{"titleHtml":"javascript"},{"titleHtml":"безопасность"}]},"570936":{"id":"570936","timePublished":"2021-08-19T12:01:01+00:00","isCorporative":true,"lang":"ru","titleHtml":"Как в восемь раз уменьшить количество DNS-запросов в Go","editorVersion":"2.0","postType":"article","postLabels":[],"author":{"id":"25866","alias":"Stamm","fullname":"Загиров Рустам","avatarUrl":"\u002F\u002Fhabrastorage.org\u002Fgetpro\u002Fhabr\u002Favatars\u002F53b\u002Ff27\u002Fb78\u002F53bf27b781b1854af60a1abc7ff4056c.jpg","speciality":"Kubernetes guy"},"statistics":{"commentsCount":0,"favoritesCount":17,"readingCount":1265,"score":18,"votesCount":18},"hubs":[{"relatedData":null,"id":"22135","alias":"ozontech","type":"corporative","title":"Блог компании Ozon Tech","titleHtml":"Блог компании Ozon Tech","isProfiled":false},{"relatedData":null,"id":"4","alias":"hi","type":"collective","title":"Высокая производительность","titleHtml":"Высокая производительность","isProfiled":true},{"relatedData":null,"id":"17708","alias":"dns","ty ...
# <script defer="" src="https://assets.habr.com/habr-web/js/chunk-vendors.9e4ba848.js"></script><script defer="" src="https://assets.habr.com/habr-web/js/page-flows.a3016599.js"></script><script defer="" src="https://assets.habr.com/habr-web/js/app.5d04126c.js"></script>
# <script>
#       (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#       })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#     </script>
# <script type="text/javascript">
#     (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
#     m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
#     (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
#     ym(24049213, "init", {
#       defer:true,
#       trackLinks:true,
#       accurateTrackBounce:true,
#       webvisor:false,
#     });
#   </script>
# <noscript>
# <div>
# <img alt="" src="https://mc.yandex.ru/watch/24049213" style="position:absolute; left:-9999px;">
# </img></div>
# </noscript>
# <script type="text/javascript">
#       window.addEventListener('load', function () {
#         setTimeout(() => {
#           const img = new Image();
#           img.src = 'https://vk.com/rtrg?p=VK-RTRG-421343-57vKE';
#         }, 0);
#       });
#     </script>
# </body>
# </html>

# %%
# из текста домашнего задания так и не понял с чем нужно работать на habr.com: со статьями или с новостями? Это все-таки разные 
# блоки на сайте. У новостей нет preview-информации, есть только заголовки. Но с другой стороны во время вебинара было сказано,
# что ДЗ "никак не связано с хабами, оно связано с текстами НОВОСТЕЙ". Решил, что буду производить поиск по статьям (не используя хабы)

posts = soup.find_all('article', class_='tm-articles-list__item') # получем список тегов со статьями 
posts
# Out:
# [<article class="tm-articles-list__item" data-navigatable="" id="573776" tabindex="0"><div class="tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/wlkr/" title="wlkr"><div class="tm-entity-image"><svg class="tm-svg-img tm-image-placeholder tm-image-placeholder_blue" height="24" width="24"><!-- --><use xlink:href="/img/megazord-v24.cee85629.svg#placeholder-user"></use></svg></div></a><span class="tm-user-info__user"><a class="tm-user-info__username" href="/ru/users/wlkr/">
#        wlkr
#      </a></span></span><span class="tm-article-snippet__datetime-published"><time datetime="2021-08-19T15:07:46.000Z" title="2021-08-19, 18:07">сегодня в 18:07</time></span></div><!-- --></div><h2 class="tm-article-snippet__title tm-article-snippet__title_h2"><a class="tm-article-snippet__title-link" data-article-link="" href="/ru/post/573776/"><span>Домик в деревне и цифровые модели рельефа</span></a></h2><div class="tm-article-snippet__hubs"><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/geo/"><span>Геоинформационные сервисы</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/opendata/"><span>Открытые данные</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/data_visualization/"><span>Визуализация данных</span><!-- --></a></span></div><div class="tm-article-snippet__labels"><!-- --></div><!-- --><div class="tm-article-body tm-article-snippet__lead">
#  <div class="tm-article-snippet__cover tm-article-snippet__cover_cover"><img class="tm-article-snippet__lead-image" src="https://habrastorage.org/getpro/habr/upload_files/cc1/ad8/195/cc1ad81956c536ce435766a6c4854b3c.png" style="object-position:0% 0%;"/></div><div class="article-formatted-body article-formatted-body_version-2"><p>Сбылась мечта вашего детства—вы присмотрели себе домик в деревне​! Домик в отличном состоянии, из окна прекрасный вид, под самым окном тихо журчит речка Переплюйка, жизнь прекрасна! Вы совсем было собрались его купить, но вдруг достали телефон и зачем-то решили почитать новости. А там—изменения климата, очередное наводнение неважно где, с разрушениями и жертвами. И вдруг вы с беспокойством смотрите на речку Переплюйку прямо перед вами, и думаете, а не превратится ли она в случае чего в бурный поток, смывающий всё нажитое непосильным трудом? Давайте посмотрим, чем технологии ГИС (геоинформационных систем) могут вам помочь, и почему свободный доступ граждан к географическим данным полезен для принятия решений.</p></div><a class="tm-article-snippet__readmore" href="/ru/post/573776/"><span>Читать далее</span></a></div></div><div class="tm-data-icons"><!-- --><div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon_small" height="16" width="16"><title>Рейтинг</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-rating"></use></svg><span class="tm-votes-meter__value tm-votes-meter__value_small">0</span></div><span class="tm-icon-counter tm-data-icons__item" title="Количество просмотров"><svg class="tm-svg-img tm-icon-counter__icon" height="16" width="16"><title>Просмотры</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-views"></use></svg><span class="tm-icon-counter__value">1</span></span><button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon" title="Добавить в закладки"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Добавить в закладки</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-favorite"></use></svg></span><span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#      0
#    </span></button><div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/post/573776/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="16" width="16"><title>Комментарии</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-comments"></use></svg><span class="tm-article-comments-counter-link__value">
#        0
#      </span></a><!-- --></div><!-- --><div class="v-portal" style="display:none;"></div></div></article>,
#  <article class="tm-articles-list__item" data-navigatable="" id="573774" tabindex="0"><div class="tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/pureacetone/" title="pureacetone"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="24" loading="lazy" src="//habrastorage.org/r/w32/getpro/habr/avatars/053/a91/47d/053a9147d1635e229765d7f57af3db63.png" width="24"/></div></a><span class="tm-user-info__user"><a class="tm-user-info__username" href="/ru/users/pureacetone/">
#        pureacetone
#      </a></span></span><span class="tm-article-snippet__datetime-published"><time datetime="2021-08-19T15:03:34.000Z" title="2021-08-19, 18:03">сегодня в 18:03</time></span></div><!-- --></div><h2 class="tm-article-snippet__title tm-article-snippet__title_h2"><a class="tm-article-snippet__title-link" data-article-link="" href="/ru/company/itsoft/blog/573774/"><span>GOSTCoin. История первой криптовалюты в I2P</span></a></h2><div class="tm-article-snippet__hubs"><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/company/itsoft/blog/"><span>Блог компании ITSOFT</span><!-- --></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/crypto/"><span>Криптография</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/i2p/"><span>I2P</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/cryptocurrency/"><span>Криптовалюты</span><!-- --></a></span></div><div class="tm-article-snippet__labels"><!-- --></div><!-- --><div class="tm-article-body tm-article-snippet__lead">
#  <div class="tm-article-snippet__cover tm-article-snippet__cover_cover"><img class="tm-article-snippet__lead-image" src="https://habrastorage.org/getpro/habr/upload_files/fbe/a52/692/fbea526927d0b07126d9fcfa57ce34ca.jpg" style="object-position:0% 0%;"/></div><div class="article-formatted-body article-formatted-body_version-2"><p>Эта статья посвящена криптовалюте, в основе которой лежит стандартизированная российская криптография. В отличие от других ноу-неймов, ее разработала команда с именем, а сама валюта не рекламировалась в инстаграм-профилях с миллионной аудиторией. Из материала вы узнаете историю первой в мире криптомонеты, которая стала полностью адаптирована для работы через <a href="https://habr.com/ru/post/552072/">I2P</a> без единой нужды обращаться в обычный интернет, где запросы подвержены перехвату, анализу и блокировкам.</p></div><a class="tm-article-snippet__readmore" href="/ru/company/itsoft/blog/573774/"><span>Читать далее</span></a></div></div><div class="tm-data-icons"><!-- --><div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon_small" height="16" width="16"><title>Рейтинг</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-rating"></use></svg><span class="tm-votes-meter__value tm-votes-meter__value_small">0</span></div><span class="tm-icon-counter tm-data-icons__item" title="Количество просмотров"><svg class="tm-svg-img tm-icon-counter__icon" height="16" width="16"><title>Просмотры</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-views"></use></svg><span class="tm-icon-counter__value">10</span></span><button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon" title="Добавить в закладки"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Добавить в закладки</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-favorite"></use></svg></span><span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#      0
#    </span></button><div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/company/itsoft/blog/573774/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="16" width="16"><title>Комментарии</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-comments"></use></svg><span class="tm-article-comments-counter-link__value">
#        0
#      </span></a><!-- --></div><!-- --><div class="v-portal" style="display:none;"></div></div></article>,
#  <article class="tm-articles-list__item" data-navigatable="" id="573772" tabindex="0"><div class="tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/hedgehog_on_rainbow/" title="hedgehog_on_rainbow"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="24" loading="lazy" src="//habrastorage.org/r/w32/getpro/habr/avatars/5f2/458/0d5/5f24580d57ae3d6961d9da7f5372641a.png" width="24"/></div></a><span class="tm-user-info__user"><a class="tm-user-info__username" href="/ru/users/hedgehog_on_rainbow/">
#        hedgehog_on_rainbow
#      </a></span></span><span class="tm-article-snippet__datetime-published"><time datetime="2021-08-19T14:52:40.000Z" title="2021-08-19, 17:52">сегодня в 17:52</time></span></div><!-- --></div><h2 class="tm-article-snippet__title tm-article-snippet__title_h2"><a class="tm-article-snippet__title-link" data-article-link="" href="/ru/company/exness/blog/573772/"><span>MasterCard откажется от магнитных полос на картах</span></a></h2><div class="tm-article-snippet__hubs"><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/company/exness/blog/"><span>Блог компании Exness</span><!-- --></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/infosecurity/"><span>Информационная безопасность</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/finance/"><span>Финансы в IT</span><!-- --></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/futurenow/"><span>Будущее здесь</span><!-- --></a></span></div><div class="tm-article-snippet__labels"><!-- --></div><!-- --><div class="tm-article-body tm-article-snippet__lead">
#  <div class="tm-article-snippet__cover tm-article-snippet__cover_cover"><img class="tm-article-snippet__lead-image" src="https://habrastorage.org/getpro/habr/upload_files/e80/006/3e7/e800063e7b2ac5930d064fe2012d07b4.jpeg" style="object-position:0% 0%;"/></div><div class="article-formatted-body article-formatted-body_version-2"><p>Уходит целая эпоха: Корпорация MasterCard пообещала <a href="https://www.mastercard.com/news/perspectives/2021/magnetic-stripe/"><u>отказаться</u></a> от магнитной полосы на картах к 2033 году и перейти к таким безопасным альтернативам как чипы и бесконтактные платежи. </p><p>А мы решили вспомнить о том, как все начиналось, и поразмышлять над тем, что ждет нас после отказа от магнитных полос. </p></div><a class="tm-article-snippet__readmore" href="/ru/company/exness/blog/573772/"><span>Читать далее</span></a></div></div><div class="tm-data-icons"><!-- --><div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon_small" height="16" width="16"><title>Всего голосов 4: ↑4 и ↓0</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-rating"></use></svg><span class="tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_small" title="Всего голосов 4: ↑4 и ↓0">+4</span></div><span class="tm-icon-counter tm-data-icons__item" title="Количество просмотров"><svg class="tm-svg-img tm-icon-counter__icon" height="16" width="16"><title>Просмотры</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-views"></use></svg><span class="tm-icon-counter__value">279</span></span><button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon" title="Добавить в закладки"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Добавить в закладки</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-favorite"></use></svg></span><span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#      0
#    </span></button><div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/company/exness/blog/573772/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="16" width="16"><title>Комментарии</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-comments"></use></svg><span class="tm-article-comments-counter-link__value">
#        1
#      </span></a><!-- --></div><!-- --><div class="v-portal" style="display:none;"></div></div></article>,
#  <article class="tm-articles-list__item" data-navigatable="" id="573470" tabindex="0"><div class="tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/gayka_m8/" title="gayka_m8"><div class="tm-entity-image"><svg class="tm-svg-img tm-image-placeholder tm-image-placeholder_pink" height="24" width="24"><!-- --><use xlink:href="/img/megazord-v24.cee85629.svg#placeholder-user"></use></svg></div></a><span class="tm-user-info__user"><a class="tm-user-info__username" href="/ru/users/gayka_m8/">
#        gayka_m8
#      </a></span></span><span class="tm-article-snippet__datetime-published"><time datetime="2021-08-19T14:13:01.000Z" title="2021-08-19, 17:13">сегодня в 17:13</time></span></div><!-- --></div><h2 class="tm-article-snippet__title tm-article-snippet__title_h2"><a class="tm-article-snippet__title-link" data-article-link="" href="/ru/company/dododev/blog/573470/"><span>Молодые не идут в .NET. Правда или нет?</span></a></h2><div class="tm-article-snippet__hubs"><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/company/dododev/blog/"><span>Блог компании Dodo Engineering</span><!-- --></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/webdev/"><span>Разработка веб-сайтов</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/net/"><span>.NET</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/csharp/"><span>C#</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/career/"><span>Карьера в IT-индустрии</span><!-- --></a></span></div><div class="tm-article-snippet__labels"><!-- --></div><!-- --><div class="tm-article-body tm-article-snippet__lead">
#  <div class="tm-article-snippet__cover tm-article-snippet__cover_cover"><img class="tm-article-snippet__lead-image" src="https://habrastorage.org/getpro/habr/upload_files/db0/72c/a5b/db072ca5b9aee6faf3b07d37d0eec777.png" style="object-position:0% 0%;"/></div><div class="article-formatted-body article-formatted-body_version-2"><p>Как-то раз наши разработчики тёрли за что-то важное у кофемашины и между делом стебались, что им скоро придётся уйти из .NET, потому что язык вымирает. Шутки шутками, но мысль застряла в голове и не отпускала.</p><p>Чтобы прояснить ситуацию, мы заглянули в DotNet-сообщество, сходили  к ребятам из Microsoft, Райффайзенбанка, Контура, CUSTIS и задали несколько вопросов. Вы тоже возьмите чашечку кофе, устройтесь поудобнее, поразмышляйте о будущем .NET и поделитесь своими мыслями в комментариях.</p></div><a class="tm-article-snippet__readmore" href="/ru/company/dododev/blog/573470/"><span>Читать далее</span></a></div></div><div class="tm-data-icons"><!-- --><div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon_small" height="16" width="16"><title>Всего голосов 10: ↑9 и ↓1</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-rating"></use></svg><span class="tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_small" title="Всего голосов 10: ↑9 и ↓1">+8</span></div><span class="tm-icon-counter tm-data-icons__item" title="Количество просмотров"><svg class="tm-svg-img tm-icon-counter__icon" height="16" width="16"><title>Просмотры</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-views"></use></svg><span class="tm-icon-counter__value">1.4K</span></span><button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon" title="Добавить в закладки"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Добавить в закладки</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-favorite"></use></svg></span><span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#      3
#    </span></button><div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/company/dododev/blog/573470/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="16" width="16"><title>Комментарии</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-comments"></use></svg><span class="tm-article-comments-counter-link__value">
#        5
#      </span></a><!-- --></div><!-- --><div class="v-portal" style="display:none;"></div></div></article>,
#  <article class="tm-articles-list__item" data-navigatable="" id="573766" tabindex="0"><div class="tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/PPR/" title="PPR"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="24" loading="lazy" src="//habrastorage.org/r/w32/getpro/habr/avatars/474/1fb/0f8/4741fb0f8dabdbe1480fbc5ce537d15b.png" width="24"/></div></a><span class="tm-user-info__user"><a class="tm-user-info__username" href="/ru/users/PPR/">
#        PPR
#      </a></span></span><span class="tm-article-snippet__datetime-published"><time datetime="2021-08-19T13:56:20.000Z" title="2021-08-19, 16:56">сегодня в 16:56</time></span></div><!-- --></div><h2 class="tm-article-snippet__title tm-article-snippet__title_h2"><a class="tm-article-snippet__title-link" data-article-link="" href="/ru/post/573766/"><span>Обдурить Шаи-Хулуда</span></a></h2><div class="tm-article-snippet__hubs"><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/infosecurity/"><span>Информационная безопасность</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/sys_admin/"><span>Системное администрирование</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/bigdata/"><span>Big Data</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span></div><div class="tm-article-snippet__labels"><!-- --></div><!-- --><div class="tm-article-body tm-article-snippet__lead">
#  <div class="tm-article-snippet__cover tm-article-snippet__cover_cover"><img class="tm-article-snippet__lead-image" src="https://habrastorage.org/getpro/habr/upload_files/6e5/ee3/2d4/6e5ee32d47601f9c59c671c6e8e3672c.jpg" style="object-position:0% 0%;"/></div><div class="article-formatted-body article-formatted-body_version-2"><p>Привет, Хабр! </p><p>Сегодня поговорим о «больших данных» в кибербезопасности, а точнее, о том насколько легко - или сложно - обойти защиту, использующую Big Data. Иначе говоря, как надурить и объегорить передовые системы обнаружения угроз, мимо всевидящего ока которых, как утверждают маркетологи, лишний байт не проскочит.</p><p>О чём, собственно говоря, речь? О системах идентификации кибератак, использующих анализ «больших данных» в качестве одного из основных инструментов выявления подозрительной активности, - системы SIEM и XDR. Такие платформы в принципе ориентированы на средний и крупный бизнес, крупные сети и облачную инфраструктуру, в которой происходят миллионы событий ежечасно. Естественно, и речи не может идти о том, чтобы анализировать их «вручную», всё это осуществляется с интенсивным использованием технических средств, хотя наличие квалифицированных специалистов - и в области «больших данных», и в области кибербезопасности, - абсолютно необходимая составляющая.</p><p>Что делают такие системы? Позволяют идентифицировать в огромных (Big, очень Big) массивах структурированных и неструктурированных данных признаки несанкционированной активности. Иначе говоря, кибератак. Учитывая, что в средних размеров сети, насчитывающей 20 тысяч конечных точек, за сутки транслируется около 50 терабайт данных, задача «прошерстить» всё это становится очень неординарной.</p><p>Для этого существуют множественные алгоритмы. Основным критерием качества платформ обнаружения угроз - в частности, XDR, является точность обнаружения аномалий в системах, которые они защищают. <strong>XDR</strong>-решения, как правило, включают в себя и SIEM-платформы, отвечающие за сбор и обработку событий, и <strong>EDR</strong> - обнаружение и реагирование на аномалии, и <strong>UBA/UEBA</strong> - системы, которые собирают (большие) массивы данных о действиях пользователей и/или конечных точек, серверов и сетевого оборудования, а затем с помощью алгоритмов машинного обучения выстраивают модели поведения и пытаются выявить отклонения от них. </p></div><a class="tm-article-snippet__readmore" href="/ru/post/573766/"><span>Читать далее</span></a></div></div><div class="tm-data-icons"><!-- --><div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon_small" height="16" width="16"><title>Всего голосов 1: ↑1 и ↓0</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-rating"></use></svg><span class="tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_small" title="Всего голосов 1: ↑1 и ↓0">+1</span></div><span class="tm-icon-counter tm-data-icons__item" title="Количество просмотров"><svg class="tm-svg-img tm-icon-counter__icon" height="16" width="16"><title>Просмотры</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-views"></use></svg><span class="tm-icon-counter__value">339</span></span><button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon" title="Добавить в закладки"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Добавить в закладки</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-favorite"></use></svg></span><span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#      1
#    </span></button><div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/post/573766/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="16" width="16"><title>Комментарии</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-comments"></use></svg><span class="tm-article-comments-counter-link__value">
#        0
#      </span></a><!-- --></div><!-- --><div class="v-portal" style="display:none;"></div></div></article>,
#  <article class="tm-articles-list__item" data-navigatable="" id="569270" tabindex="0"><div class="tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/lelyakuznetsova/" title="lelyakuznetsova"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="24" loading="lazy" src="//habrastorage.org/r/w32/getpro/habr/avatars/fc3/c4a/165/fc3c4a1651f7c92e5166a1883b1cc5bb.jpg" width="24"/></div></a><span class="tm-user-info__user"><a class="tm-user-info__username" href="/ru/users/lelyakuznetsova/">
#        lelyakuznetsova
#      </a></span></span><span class="tm-article-snippet__datetime-published"><time datetime="2021-08-19T13:55:31.000Z" title="2021-08-19, 16:55">сегодня в 16:55</time></span></div><!-- --></div><h2 class="tm-article-snippet__title tm-article-snippet__title_h2"><a class="tm-article-snippet__title-link" data-article-link="" href="/ru/company/jugru/blog/569270/"><span>Эффективный поиск XSS-уязвимостей</span></a></h2><div class="tm-article-snippet__hubs"><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/company/jugru/blog/"><span>Блог компании JUG Ru Group</span><!-- --></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/infosecurity/"><span>Информационная безопасность</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/javascript/"><span>JavaScript</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/web_testing/"><span>Тестирование веб-сервисов</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/tech_events/"><span>Конференции</span><!-- --></a></span></div><div class="tm-article-snippet__labels"><!-- --></div><!-- --><div class="tm-article-body tm-article-snippet__lead">
#  <!-- --><div class="article-formatted-body article-formatted-body_version-1"><p><img src="https://habrastorage.org/webt/pe/ed/5c/peed5cpoi-4fqgjnbv4l3faam0k.jpeg"/></p><br/>
#  <p>Про XSS-уязвимости известно давным-давно — казалось бы, нужен ли миру ещё один материал о них? Но когда <strong>Иван Румак</strong>, занимающийся тестированием безопасности, поделился методологией их поиска на нашей конференции <strong><a href="https://heisenbug-moscow.ru/?utm_source=habr&amp;utm_medium=569270" rel="nofollow noopener noreferrer">Heisenbug</a></strong>, реакция зрителей оказалась очень положительной. </p><br/>
#  <p>И спустя два года у этого доклада по-прежнему растут просмотры и лайки, это один из самых востребованных материалов Heisenbug. Поэтому теперь мы решили, что многим будет полезна текстовая версия, и сделали ее для Хабра.</p><br/>
#  <p>Под катом — и текст, и видео. Далее повествование идет от лица Ивана.</p></div><a class="tm-article-snippet__readmore" href="/ru/company/jugru/blog/569270/"><span>Читать дальше →</span></a></div></div><div class="tm-data-icons"><!-- --><div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon_small" height="16" width="16"><title>Всего голосов 1: ↑1 и ↓0</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-rating"></use></svg><span class="tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_small" title="Всего голосов 1: ↑1 и ↓0">+1</span></div><span class="tm-icon-counter tm-data-icons__item" title="Количество просмотров"><svg class="tm-svg-img tm-icon-counter__icon" height="16" width="16"><title>Просмотры</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-views"></use></svg><span class="tm-icon-counter__value">300</span></span><button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon" title="Добавить в закладки"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Добавить в закладки</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-favorite"></use></svg></span><span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#      8
#    </span></button><div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/company/jugru/blog/569270/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="16" width="16"><title>Комментарии</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-comments"></use></svg><span class="tm-article-comments-counter-link__value">
#        3
#      </span></a><!-- --></div><!-- --><div class="v-portal" style="display:none;"></div></div></article>,
#  <article class="tm-articles-list__item" data-navigatable="" id="573562" tabindex="0"><div class="tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/skficha/" title="skficha"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="24" loading="lazy" src="//habrastorage.org/r/w32/getpro/habr/avatars/f7e/eb5/f88/f7eeb5f88b7b2cabb26c8458b53855db.jpg" width="24"/></div></a><span class="tm-user-info__user"><a class="tm-user-info__username" href="/ru/users/skficha/">
#        skficha
#      </a></span></span><span class="tm-article-snippet__datetime-published"><time datetime="2021-08-19T13:53:51.000Z" title="2021-08-19, 16:53">сегодня в 16:53</time></span></div><!-- --></div><h2 class="tm-article-snippet__title tm-article-snippet__title_h2"><a class="tm-article-snippet__title-link" data-article-link="" href="/ru/company/adapty/blog/573562/"><span>iOS in-app purchases, часть 5: обработка ошибок SKErrors</span></a></h2><div class="tm-article-snippet__hubs"><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/company/adapty/blog/"><span>Блог компании Adapty</span><!-- --></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/ios_dev/"><span>Разработка под iOS</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/mobile_dev/"><span>Разработка мобильных приложений</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span></div><div class="tm-article-snippet__labels"><div class="tm-article-snippet__label"><span>
#            Tutorial
#          </span></div></div><!-- --><div class="tm-article-body tm-article-snippet__lead">
#  <div class="tm-article-snippet__cover tm-article-snippet__cover_cover"><img class="tm-article-snippet__lead-image" src="https://habrastorage.org/getpro/habr/upload_files/fa4/a13/24b/fa4a1324b20e3be3f40f753a37a0dce0.png" style="object-position:0% 0%;"/></div><div class="article-formatted-body article-formatted-body_version-2"><p>В этом посте разбираем полный список SKErrors: что они значат и как их обрабатывать. Каждую ошибку мы рассмотрим в трёх аспектах: как она возникает, что с ней делать и какое сообщение показывать пользователю в уведомлении об ошибке.</p><p>Это пятая статья из нашей серии, посвящённой внедрению покупок на iOS. Познакомиться с предыдущими можно по ссылкам:</p><p><a href="https://habr.com/ru/company/adapty/blog/568902/"><u>1. Конфигурация и добавление в проект.</u></a></p><p><a href="https://habr.com/ru/company/adapty/blog/571122/"><u>2. Инициализация и обработка покупок.</u></a></p><p><a href="https://habr.com/ru/company/adapty/blog/572370/"><u>3. Серверная верификация покупок.</u></a></p><p><a href="https://habr.com/ru/company/adapty/blog/571960/">4. Тестирование покупок.</a></p></div><a class="tm-article-snippet__readmore" href="/ru/company/adapty/blog/573562/"><span>Читать далее</span></a></div></div><div class="tm-data-icons"><!-- --><div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon_small" height="16" width="16"><title>Рейтинг</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-rating"></use></svg><span class="tm-votes-meter__value tm-votes-meter__value_small">0</span></div><span class="tm-icon-counter tm-data-icons__item" title="Количество просмотров"><svg class="tm-svg-img tm-icon-counter__icon" height="16" width="16"><title>Просмотры</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-views"></use></svg><span class="tm-icon-counter__value">45</span></span><button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon" title="Добавить в закладки"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Добавить в закладки</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-favorite"></use></svg></span><span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#      4
#    </span></button><div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/company/adapty/blog/573562/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="16" width="16"><title>Комментарии</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-comments"></use></svg><span class="tm-article-comments-counter-link__value">
#        0
#      </span></a><!-- --></div><!-- --><div class="v-portal" style="display:none;"></div></div></article>,
#  <article class="tm-articles-list__item" data-navigatable="" id="573726" tabindex="0"><div class="tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/honyaki/" title="honyaki"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="24" loading="lazy" src="//habrastorage.org/r/w32/getpro/habr/avatars/96e/81d/bc0/96e81dbc01247c6c855b1806b355efa3.jpg" width="24"/></div></a><span class="tm-user-info__user"><a class="tm-user-info__username" href="/ru/users/honyaki/">
#        honyaki
#      </a></span></span><span class="tm-article-snippet__datetime-published"><time datetime="2021-08-19T13:18:00.000Z" title="2021-08-19, 16:18">сегодня в 16:18</time></span></div><!-- --></div><h2 class="tm-article-snippet__title tm-article-snippet__title_h2"><a class="tm-article-snippet__title-link" data-article-link="" href="/ru/company/skillfactory/blog/573726/"><span>Как запустить Jupyter Notebook в браузере без бэкенда</span></a></h2><div class="tm-article-snippet__hubs"><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/company/skillfactory/blog/"><span>Блог компании SkillFactory</span><!-- --></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/webdev/"><span>Разработка веб-сайтов</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/python/"><span>Python</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/programming/"><span>Программирование</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/webassembly/"><span>WebAssembly</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span></div><div class="tm-article-snippet__labels"><div class="tm-article-snippet__label"><span>
#            Перевод
#          </span></div></div><!-- --><div class="tm-article-body tm-article-snippet__lead">
#  <div class="tm-article-snippet__cover tm-article-snippet__cover_cover"><img class="tm-article-snippet__lead-image" src="https://habrastorage.org/getpro/habr/upload_files/afc/29c/a10/afc29ca10ef9f1ee31bac3cc01fff530.png" style="object-position:0% 0%;"/></div><div class="article-formatted-body article-formatted-body_version-2"><p>К старту нашего флагманского <a href="https://skillfactory.ru/dstpro?utm_source=habr&amp;utm_medium=habr&amp;utm_campaign=article&amp;utm_content=data-science_dspr_190821&amp;utm_term=lead">курса по Data Science</a> представляем перевод обзора JupyterLite прямо из блога его разработчиков. JupyterLite — это перезагрузка множества попыток создать полный статический выполняемый в браузере дистрибутив Jupyter, чтобы не было необходимости запускать сервер Jupyter. </p><p>Цель проекта — дать лёгкую вычислительную среду в браузере, доступную по одному клику спустя несколько секунд, без установки чего-либо на устройство конечного пользователя. При работе с дистрибутивами в браузере не нужно предоставлять среду выполнения на бэкенде. Приложение в основном представляет собой набор статических файлов, поэтому проще масштабируется и его легче развёртывать.</p></div><a class="tm-article-snippet__readmore" href="/ru/company/skillfactory/blog/573726/"><span>Читать далее</span></a></div></div><div class="tm-data-icons"><!-- --><div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon_small" height="16" width="16"><title>Всего голосов 5: ↑5 и ↓0</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-rating"></use></svg><span class="tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_small" title="Всего голосов 5: ↑5 и ↓0">+5</span></div><span class="tm-icon-counter tm-data-icons__item" title="Количество просмотров"><svg class="tm-svg-img tm-icon-counter__icon" height="16" width="16"><title>Просмотры</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-views"></use></svg><span class="tm-icon-counter__value">621</span></span><button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon" title="Добавить в закладки"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Добавить в закладки</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-favorite"></use></svg></span><span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#      10
#    </span></button><div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/company/skillfactory/blog/573726/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="16" width="16"><title>Комментарии</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-comments"></use></svg><span class="tm-article-comments-counter-link__value">
#        0
#      </span></a><!-- --></div><!-- --><div class="v-portal" style="display:none;"></div></div></article>,
#  <article class="tm-articles-list__item" data-navigatable="" id="573718" tabindex="0"><div class="tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/torquey/" title="torquey"><div class="tm-entity-image"><svg class="tm-svg-img tm-image-placeholder tm-image-placeholder_pink" height="24" width="24"><!-- --><use xlink:href="/img/megazord-v24.cee85629.svg#placeholder-user"></use></svg></div></a><span class="tm-user-info__user"><a class="tm-user-info__username" href="/ru/users/torquey/">
#        torquey
#      </a></span></span><span class="tm-article-snippet__datetime-published"><time datetime="2021-08-19T13:15:22.000Z" title="2021-08-19, 16:15">сегодня в 16:15</time></span></div><!-- --></div><h2 class="tm-article-snippet__title tm-article-snippet__title_h2"><a class="tm-article-snippet__title-link" data-article-link="" href="/ru/company/mailru/blog/573718/"><span>NLP At Scale: вся правда о предобученных моделях в Почте Mail.ru (часть 1)</span></a></h2><div class="tm-article-snippet__hubs"><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/company/mailru/blog/"><span>Блог компании Mail.ru Group</span><!-- --></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/spam/"><span>Спам и антиспам</span><!-- --></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/infosecurity/"><span>Информационная безопасность</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/machine_learning/"><span>Машинное обучение</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span></div><div class="tm-article-snippet__labels"><!-- --></div><!-- --><div class="tm-article-body tm-article-snippet__lead">
#  <!-- --><div class="article-formatted-body article-formatted-body_version-1"><div style="text-align:center;"><img src="https://habrastorage.org/webt/_8/vf/qy/_8vfqyknxlljr-ns1upxc5gxuqg.jpeg"/></div><br/>
#  Антиспам Почты Mail.ru — это симбиоз продуктовой логики и инфраструктурных технологий, про который мы решили более подробно рассказать. В основе конечно же лежит инфраструктура, с помощью которой мы получаем возможности для развития моделей машинного обучения, а также платформа ядра, которая обеспечивает работу антиспама в онлайне. Продуктовая логика представлена в виде большого количества эвристик (куда без них) и ручных правил. На вершине продуктовой пирамиды пребывает стек моделей машинного обучения, хотя положение на вершине в данном случае достаточно условно.<br/>
#  <br/>
#  В этой статье мы заберемся на эту вершину, где в последнее время часто вбивают новые колышки текстовые модели. Мы спроецируем мир текстовых ML-моделей на наш сервис, поговорим про эволюцию и решение задач Почты, связанных с текстами. Запасайтесь кислородом и свободным временем.<br/></div><a class="tm-article-snippet__readmore" href="/ru/company/mailru/blog/573718/"><span>Читать дальше →</span></a></div></div><div class="tm-data-icons"><!-- --><div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon_small" height="16" width="16"><title>Всего голосов 3: ↑3 и ↓0</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-rating"></use></svg><span class="tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_small" title="Всего голосов 3: ↑3 и ↓0">+3</span></div><span class="tm-icon-counter tm-data-icons__item" title="Количество просмотров"><svg class="tm-svg-img tm-icon-counter__icon" height="16" width="16"><title>Просмотры</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-views"></use></svg><span class="tm-icon-counter__value">153</span></span><button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon" title="Добавить в закладки"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Добавить в закладки</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-favorite"></use></svg></span><span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#      3
#    </span></button><div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/company/mailru/blog/573718/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="16" width="16"><title>Комментарии</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-comments"></use></svg><span class="tm-article-comments-counter-link__value">
#        1
#      </span></a><!-- --></div><!-- --><div class="v-portal" style="display:none;"></div></div></article>,
#  <article class="tm-articles-list__item" data-navigatable="" id="573756" tabindex="0"><div class="tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/Varonis/" title="Varonis"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="24" loading="lazy" src="//habrastorage.org/r/w32/getpro/habr/avatars/8dd/f9a/ac9/8ddf9aac958bfefdebe7c893c23693ba.png" width="24"/></div></a><span class="tm-user-info__user"><a class="tm-user-info__username" href="/ru/users/Varonis/">
#        Varonis
# ...
#        MainVoid
#      </a></span></span><span class="tm-article-snippet__datetime-published"><time datetime="2021-08-19T11:54:04.000Z" title="2021-08-19, 14:54">сегодня в 14:54</time></span></div><!-- --></div><h2 class="tm-article-snippet__title tm-article-snippet__title_h2"><a class="tm-article-snippet__title-link" data-article-link="" href="/ru/company/agima/blog/573690/"><span>Как найти идеального кандидата, и что делать с неидеальными</span></a></h2><div class="tm-article-snippet__hubs"><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/company/agima/blog/"><span>Блог компании Агентство AGIMA</span><!-- --></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/dev_management/"><span>Управление разработкой</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/pm/"><span>Управление проектами</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/hr_management/"><span>Управление персоналом</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span></div><div class="tm-article-snippet__labels"><!-- --></div><!-- --><div class="tm-article-body tm-article-snippet__lead">
#  <div class="tm-article-snippet__cover tm-article-snippet__cover_cover"><img class="tm-article-snippet__lead-image" src="https://habrastorage.org/getpro/habr/upload_files/a0d/784/b29/a0d784b293afca6a8d6f81dd0e577309.png" style="object-position:0% 0%;"/></div><div class="article-formatted-body article-formatted-body_version-2"><p>Привет, Хабр!</p><p>На связи Андрей Рыжкин, CTO AGIMA. В нашей компании более 30 команд разработки, и у каждой свой тимлид (или несколько). Людей много, а значит, их нужно нанимать, развивать, мотивировать, а иногда – расставаться с ними. Работа с людьми на мой взгляд – это одна из важнейших и при этом самых сложных функций тимлида или технического руководителя. Эта статья – об одном из аспектов этой работы: о том, как искать и нанимать разработчиков. В основе материала мой контент для курса «<a href="https://gb.ru/geek_university/leader-development-team?utm_source=habr&amp;utm_medium=article&amp;utm_campaign=pr_course"><u>Руководитель команды разработки</u></a>», а также мой опыт за весь карьерный путь от разработчика до CTO. </p></div><a class="tm-article-snippet__readmore" href="/ru/company/agima/blog/573690/"><span>Читать далее</span></a></div></div><div class="tm-data-icons"><!-- --><div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon_small" height="16" width="16"><title>Всего голосов 13: ↑13 и ↓0</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-rating"></use></svg><span class="tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_small" title="Всего голосов 13: ↑13 и ↓0">+13</span></div><span class="tm-icon-counter tm-data-icons__item" title="Количество просмотров"><svg class="tm-svg-img tm-icon-counter__icon" height="16" width="16"><title>Просмотры</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-views"></use></svg><span class="tm-icon-counter__value">1K</span></span><button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon" title="Добавить в закладки"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Добавить в закладки</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-favorite"></use></svg></span><span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#      21
#    </span></button><div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/company/agima/blog/573690/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="16" width="16"><title>Комментарии</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-comments"></use></svg><span class="tm-article-comments-counter-link__value">
#        0
#      </span></a><!-- --></div><!-- --><div class="v-portal" style="display:none;"></div></div></article>,
#  <article class="tm-articles-list__item" data-navigatable="" id="573732" tabindex="0"><div class="tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/CSoft/" title="CSoft"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="24" loading="lazy" src="//habrastorage.org/r/w32/getpro/habr/avatars/b2e/c46/e5f/b2ec46e5f90b8bb76d27d7036cef3d28.png" width="24"/></div></a><span class="tm-user-info__user"><a class="tm-user-info__username" href="/ru/users/CSoft/">
#        CSoft
#      </a></span></span><span class="tm-article-snippet__datetime-published"><time datetime="2021-08-19T11:52:21.000Z" title="2021-08-19, 14:52">сегодня в 14:52</time></span></div><!-- --></div><h2 class="tm-article-snippet__title tm-article-snippet__title_h2"><a class="tm-article-snippet__title-link" data-article-link="" href="/ru/company/nanosoft/blog/573732/"><span>Российские BIM-технологии: разработка технологических схем в Model Studio CS</span></a></h2><div class="tm-article-snippet__hubs"><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/company/nanosoft/blog/"><span>Блог компании Нанософт</span><!-- --></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/cad_cam/"><span>CAD/CAM</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/industrial_control_system/"><span>Промышленное программирование</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/technical_writing/"><span>Подготовка технической документации</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span></div><div class="tm-article-snippet__labels"><!-- --></div><!-- --><div class="tm-article-body tm-article-snippet__lead">
#  <div class="tm-article-snippet__cover tm-article-snippet__cover_cover"><img class="tm-article-snippet__lead-image" src="https://habrastorage.org/getpro/habr/upload_files/9c3/2d9/e55/9c32d9e55530bec0af8678ace6e6a801.png" style="object-position:0% 0%;"/></div><div class="article-formatted-body article-formatted-body_version-2"><p><em>Эта статья продолжает цикл публикаций о российских BIM-технологиях и посвящена программному комплексу Model Studio CS Технологические схемы, предназначенному для решения задач разработки схемных решений при проектировании разделов ТХ.</em></p><p><strong>Введение</strong></p><p>На первый взгляд разработка схемных разделов технологических решений может показаться простой и довольно тривиальной задачей. Результат в виде получившейся схемы всегда представляется простым и понятным. Но когда понимаешь, что внесенная информация и решения, принятые на этом этапе, проходят через все стадии проекта, становится ясно – для эффективной работы и сокращения числа возможных ошибок необходим удобный и надежный инструмент. Инструмент, который автоматизирует стандартные операции и позволит не отвлекаться от процесса проектирования. Такой, каким в полной мере является программный комплекс <a href="https://www.mscad.ru/programs/schemes/?utm_source=habr&amp;utm_medium=statya&amp;utm_campaign=seriya_ARM_tech_shemi">Model Studio CS Технологические схемы</a>.</p></div><a class="tm-article-snippet__readmore" href="/ru/company/nanosoft/blog/573732/"><span>Читать далее</span></a></div></div><div class="tm-data-icons"><!-- --><div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon_small" height="16" width="16"><title>Всего голосов 6: ↑6 и ↓0</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-rating"></use></svg><span class="tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_small" title="Всего голосов 6: ↑6 и ↓0">+6</span></div><span class="tm-icon-counter tm-data-icons__item" title="Количество просмотров"><svg class="tm-svg-img tm-icon-counter__icon" height="16" width="16"><title>Просмотры</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-views"></use></svg><span class="tm-icon-counter__value">153</span></span><button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon" title="Добавить в закладки"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Добавить в закладки</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-favorite"></use></svg></span><span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#      1
#    </span></button><div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/company/nanosoft/blog/573732/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="16" width="16"><title>Комментарии</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-comments"></use></svg><span class="tm-article-comments-counter-link__value">
#        0
#      </span></a><!-- --></div><!-- --><div class="v-portal" style="display:none;"></div></div></article>,
#  <article class="tm-articles-list__item" data-navigatable="" id="573720" tabindex="0"><div class="tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/redhatrussia/" title="redhatrussia"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="24" loading="lazy" src="//habrastorage.org/r/w32/getpro/habr/avatars/592/816/4a9/5928164a9c2b4d0e7693ebb16e0f792a.png" width="24"/></div></a><span class="tm-user-info__user"><a class="tm-user-info__username" href="/ru/users/redhatrussia/">
#        redhatrussia
#      </a></span></span><span class="tm-article-snippet__datetime-published"><time datetime="2021-08-19T11:45:42.000Z" title="2021-08-19, 14:45">сегодня в 14:45</time></span></div><!-- --></div><h2 class="tm-article-snippet__title tm-article-snippet__title_h2"><a class="tm-article-snippet__title-link" data-article-link="" href="/ru/company/redhatrussia/blog/573720/"><span>Шаблоны модернизации приложения с помощью Apache Kafka, Debezium и Kubernetes, часть 1</span></a></h2><div class="tm-article-snippet__hubs"><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/company/redhatrussia/blog/"><span>Блог компании Red Hat</span><!-- --></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/open_source/"><span>Open source</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/it-infrastructure/"><span>IT-инфраструктура</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/virtualization/"><span>Виртуализация</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span><span class="tm-article-snippet__hubs-item"><a class="tm-article-snippet__hubs-item-link" href="/ru/hub/dev_management/"><span>Управление разработкой</span><span class="tm-article-snippet__profiled-hub" title="Профильный хаб">*</span></a></span></div><div class="tm-article-snippet__labels"><!-- --></div><!-- --><div class="tm-article-body tm-article-snippet__lead">
#  <div class="tm-article-snippet__cover tm-article-snippet__cover_cover"><img class="tm-article-snippet__lead-image" src="https://habrastorage.org/getpro/habr/upload_files/b42/188/a59/b42188a59abd0c788050c1bf34153743.png" style="object-position:0% 0%;"/></div><div class="article-formatted-body article-formatted-body_version-2"><p><em>«Наши компьютеры создаются так же, как и наши города: долго, без планов и на руинах былого». </em>Эллен Ульман (Ellen Ullman) <a href="https://www.salon.com/1998/05/12/feature_321/">написала это в 1998 году</a>, но сегодня мы именно так и создаем современные приложения: долго, имея лишь краткосрочные планы и поверх унаследованного ПО. В этой статье мы рассмотрим несколько шаблонов и инструментов, которые, на наш взгляд, хорошо подходят для продуманной модернизации унаследованных приложений и создания современных <a href="https://developers.redhat.com/topics/event-driven">управляемых событиями систем</a>.</p></div><a class="tm-article-snippet__readmore" href="/ru/company/redhatrussia/blog/573720/"><span>Читать дальше: Шаблоны модернизации...</span></a></div></div><div class="tm-data-icons"><!-- --><div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon_small" height="16" width="16"><title>Всего голосов 3: ↑3 и ↓0</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-rating"></use></svg><span class="tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_small" title="Всего голосов 3: ↑3 и ↓0">+3</span></div><span class="tm-icon-counter tm-data-icons__item" title="Количество просмотров"><svg class="tm-svg-img tm-icon-counter__icon" height="16" width="16"><title>Просмотры</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-views"></use></svg><span class="tm-icon-counter__value">278</span></span><button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon" title="Добавить в закладки"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Добавить в закладки</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-favorite"></use></svg></span><span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#      6
#    </span></button><div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/company/redhatrussia/blog/573720/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="16" width="16"><title>Комментарии</title><use xlink:href="/img/megazord-v24.cee85629.svg#counter-comments"></use></svg><span class="tm-article-comments-counter-link__value">
#        0
#      </span></a><!-- --></div><!-- --><div class="v-portal" style="display:none;"></div></div></article>]

# %%
articles = pd.DataFrame()
for post in posts:
    text = post.text.lower()
    for word in KEYWORDS:
        if word.lower() in text:
            date  = pd.to_datetime(post.find('span', class_='tm-article-snippet__datetime-published').find('time').get('datetime')).strftime('%Y-%m-%d %H:%M:%S')
            title = post.find('a', class_='tm-article-snippet__title-link').text
            url = 'https://habr.com' + post.find('a', class_='tm-article-snippet__title-link').get('href')
            row = {'Дата': date, 'Заголовок': title, 'Ссылка': url}
            articles = pd.concat([articles, pd.DataFrame([row])], ignore_index=True)
# т.к. в какой-то статье может быть несколько ключевых слов, то в итоговом датафрейме возможно дублирование строк
# удаляем дубликаты
articles.drop_duplicates()
# Out:
#                   Дата                                          Заголовок  \
# 0  2021-08-19 13:18:00  Как запустить Jupyter Notebook в браузере без ...
# 1  2021-08-19 12:01:01  Как в восемь раз уменьшить количество DNS-запр...
#
#                                               Ссылка
# 0  https://habr.com/ru/company/skillfactory/blog/...
# 1  https://habr.com/ru/company/ozontech/blog/570936/

# %% [markdown]
# ## Дополнительная часть (необязательная)
#
# Улучшить скрипт так, чтобы он анализировал не только preview-информацию статьи, но и весь текст статьи целиком.
#
# Для этого потребуется получать страницы статей и искать по тексту внутри этой страницы.
#
# Итоговый датафрейм формировать со столбцами: <дата> - <заголовок> - <ссылка> - <текст_статьи>

# %%
# этот вариант находит чуть больше статей, т.к. ищет по всему тексту полной статьи
articles = pd.DataFrame()
for post in posts:
    # сначала получаем ссылку для каждой статьи
    url = 'https://habr.com' + post.find('a', class_='tm-article-snippet__title-link').get('href') 
    # делаем запрос по получившейся сссылке и находим тег, содержащий полную статью
    page = requests.get(url)
    full_article = BeautifulSoup(page.text, 'html.parser').find('article', class_='tm-page-article__content tm-page-article__content_inner')
    full_text = full_article.text.lower()
    for word in KEYWORDS:
        # если ключевое слово встречается в текстовом содержимом тега со статьей, то подбираем еще дату и заголовок статьи
        if word.lower() in full_text:
            date  = pd.to_datetime(post.find('span', class_='tm-article-snippet__datetime-published').find('time').get('datetime')).strftime('%Y-%m-%d %H:%M:%S')
            title = post.find('a', class_='tm-article-snippet__title-link').text
            text = full_article.find('div', class_ = 'tm-article-body').text
            row = {'Дата': date, 'Заголовок': title, 'Ссылка': url, 'Текст статьи' : text}
            articles = pd.concat([articles, pd.DataFrame([row])], ignore_index=True)
# т.к. в какой-то статье может быть несколько ключевых слов, то в итоговом датафрейме возможно дублирование строк
# удаляем дубликаты   
articles.drop_duplicates()
# Out:
#                   Дата                                          Заголовок  \
# 0  2021-08-19 14:13:01            Молодые не идут в .NET. Правда или нет?
# 2  2021-08-19 13:55:31                  Эффективный поиск XSS-уязвимостей
# 4  2021-08-19 13:18:00  Как запустить Jupyter Notebook в браузере без ...
# 5  2021-08-19 13:15:22  NLP At Scale: вся правда о предобученных модел...
# 6  2021-08-19 12:49:11  Ускорение WordPress. Тотальный разбор плагинов...
# 8  2021-08-19 12:01:01  Как в восемь раз уменьшить количество DNS-запр...
# 9  2021-08-19 11:54:04  Как найти идеального кандидата, и что делать с...
#
#                                               Ссылка  \
# 0   https://habr.com/ru/company/dododev/blog/573470/
# 2     https://habr.com/ru/company/jugru/blog/569270/
# 4  https://habr.com/ru/company/skillfactory/blog/...
# 5    https://habr.com/ru/company/mailru/blog/573718/
# 6                   https://habr.com/ru/post/573750/
# 8  https://habr.com/ru/company/ozontech/blog/570936/
# 9     https://habr.com/ru/company/agima/blog/573690/
#
#                                         Текст статьи
# 0  Как-то раз наши разработчики тёрли за что-то в...
# 2  \nПро XSS-уязвимости известно давным-давно — к...
# 4  К старту нашего флагманского курса по Data Sci...
# 5  \r\nАнтиспам Почты Mail.ru — это симбиоз проду...
# 6  В этой части я подробно рассмотрю принцип рабо...
# 8  Привет, Хабр. Меня зовут Рустам. Я работаю в O...
# 9  Поиск, подбор и найм новых сотрудников – практ...

# %% [markdown]
# ## Задание 2

# %% [markdown]
# Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса Avast Hack Ckeck(https://www.avast.com/hackcheck/). Список email-ов задаем переменной в начале кода:
# EMAIL = [xxx@x.ru, yyy@y.com]
#
# В итоге должен формироваться датафрейм со столбцами: <дата утечки> - <источник утечки> - <описание утечки>

# %%
EMAIL = ['kolya@mail.ru', 'tanya@gmail.com', 'vanya@yandex.ru', 'xxx@x.ru', 'yyy@y.com']
URL = 'https://identityprotection.avast.com/v1/web/query/site-breaches/unauthorized-data'
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36',

    'Vaar-Header-App-Product': 'hackcheck-web-avast',
    'Vaar-Header-App-Product-Name': 'hackcheck-web-avast',
    'Vaar-Header-App-Build-Version': '1.0.0',
    'Vaar-Version': '0',

    'Accept': 'application/json, text/plain, */*',
    'Content-Type': 'application/json;charset=UTF-8',
    'Host': 'identityprotection.avast.com',
    'Origin': 'https://www.avast.com',
    'Referer': 'https://www.avast.com/'
}
PAYLOAD = {'emailAddresses': EMAIL}
# Долго не получалось сделать POST запрос, выдавалась ошибка 400, хотя все атрибуты определил правильно. 
# В итоге честно взял этот кусок кода отсюда:
# https://ru.stackoverflow.com/questions/1242929/Как-загрузить-ответ-на-post-запрос-с-сайта-в-виде-json-файла

r = requests.post(URL, headers=HEADERS, json=PAYLOAD)
r
# Out:
# <Response [200]>

# %%
# для наглядности отобразим в формате JSON
r.json()
# Out:
# {'breaches': {'2': {'breachId': 2,
#    'site': 'linkedin.com',
#    'recordsCount': 158591429,
#    'description': "In 2012, online professional networking platform LinkedIn fell victim to a breach of its members' passwords. Four years later, 117 million email and password combinations from that breach appeared for sale on a dark web marketplace. \n\nThe leaked passwords had only been protected by unsalted SHA-1 cryptographic hashing, which prompted LinkedIn to enforce salted hashing after the breach. Russian national Yevgeniy Nikulin was accused of the breach and was extradited from the Czech Republic to the United States as of March 2018.",
#    'publishDate': '2016-10-21T00:00:00Z',
#    'statistics': {'usernames': 0,
#     'passwords': 111975337,
#     'emails': 158591429}},
#   '3': {'breachId': 3,
#    'site': 'adobe.com',
#    'recordsCount': 152046506,
#    'description': "In October of 2013, criminals penetrated Adobe's corporate network and the stole source code for several of its software products. The affected products included Adobe's ColdFusion web application platform as well as the Acrobat suite of products. Adobe asserts that criminals also accessed nearly three-million customer credit card records and stole login data for an undisclosed number of Adobe user accounts.",
#    'publishDate': '2016-10-21T00:00:00Z',
#    'statistics': {'usernames': 0,
#     'passwords': 129430596,
#     'emails': 152046506}},
#   '12': {'breachId': 12,
#    'site': 'vk.com',
#    'recordsCount': 110121799,
#    'description': "Popular Russian social networking platform VKontakte was breached in late 2012. Over 100 million clear-text passwords were compromised in the breach. Breached credential sets included victims' e-mail addresses, passwords, dates of birth, phone numbers and location details. The credential set was advertised on a dark web marketplace as of June 2016 for a price of one bitcoin. ",
#    'publishDate': '2016-10-29T00:00:00Z',
#    'statistics': {'usernames': 0,
#     'passwords': 107425364,
#     'emails': 104247327}},
#   '15': {'breachId': 15,
#    'site': 'imesh.com',
#    'recordsCount': 50913222,
#    'description': 'In June 2016, a cache of over 51 million user credentials from the online sharing service iMesh appeared for sale on a dark web marketplace.  The database contained user email addresses, usernames, passwords, IP addresses and location.',
#    'publishDate': '2016-10-23T00:00:00Z',
#    'statistics': {'usernames': 50909015,
#     'passwords': 50913222,
#     'emails': 50913222}},
#   '41': {'breachId': 41,
#    'site': 'dropbox.com',
#    'recordsCount': 68591031,
#    'description': "Cloud storage company Dropbox suffered a major data breach in 2012. Criminals leveraged stolen employee login credentials to access a project document containing user email addresses and hashed passwords. Thanks to employees' passwords reuse between work and personal accounts, several matches were exploited, which ultimately lead to the full scope of the breach. It wasn't until August 2016 that Dropbox confirmed over 68 million user credentials had been breached in 2012. In response, DropBox enforced a password reset for its users. ",
#    'publishDate': '2016-10-24T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 68591031, 'emails': 68591031}},
#   '2961': {'breachId': 2961,
#    'site': 'cdprojektred.com',
#    'recordsCount': 1871459,
#    'description': "In March 2016, CDProjektRed.com.com's forum database was breached. The attacker may have exploited a vulnerability in vBulletin. The stolen data contains over 1,870,000 user records including associated usernames, email addresses, hashed passwords, and salts. The leaked credentials are being shared and sold privately on the dark web.",
#    'publishDate': '2017-01-31T00:00:00Z',
#    'statistics': {'usernames': 1871410,
#     'passwords': 1871457,
#     'emails': 1871289}},
#   '3164': {'breachId': 3164,
#    'site': 'cfire.mail.ru',
#    'recordsCount': 12880232,
#    'description': "In July and August of 2016, two criminals carried out attacks on three separate forums hosted by Mail.ru, including CFire. The hackers used known SQL injection vulnerabilities found in older vBulletin forum software to obtain access to the databases. Shortly after the breach itself, the contents of CFire's database were leaked publicly. The database contains usernames, email addresses, and MD5 hashed passwords for just under 13 million users.",
#    'publishDate': '2017-02-14T00:00:00Z',
#    'statistics': {'usernames': 12880232,
#     'passwords': 12880222,
#     'emails': 12845820}},
#   '3176': {'breachId': 3176,
#    'site': 'parapa.mail.ru',
#    'recordsCount': 5029003,
#    'description': "In July and August 2016, two criminals executed attacks against three separate forums hosted by Mail.ru including the Russian forum Parapa. Shortly after the breach occurred, the contents of Parapa's database were leaked publicly. The database contains usernames, email addresses, and hashed passwords for around 5 million users.",
#    'publishDate': '2017-02-14T00:00:00Z',
#    'statistics': {'usernames': 5029000,
#     'passwords': 5029003,
#     'emails': 4941344}},
#   '3520': {'breachId': 3520,
#    'site': 'globalreach.eu',
#    'recordsCount': 921298,
#    'description': "In 2016, Global Reach Technology's database was allegedly breached. The stolen records are being shared among private cirlces on the darknet.",
#    'publishDate': '2017-03-15T00:00:00Z',
#    'statistics': {'usernames': 13492, 'passwords': 921298, 'emails': 907696}},
#   '3587': {'breachId': 3587,
#    'site': 'rayli.com.cn',
#    'recordsCount': 4844179,
#    'description': "On an unconfirmed date, Chinese gossip site Rayli's user database was allegedly breached. The stolen data contains over 4,850,000 records including email addresses, usernames, passwords, and salts. The compromised data is being shared privately among closed and trusted groups.",
#    'publishDate': '2017-03-01T00:00:00Z',
#    'statistics': {'usernames': 4841886,
#     'passwords': 4833694,
#     'emails': 4803135}},
#   '3669': {'breachId': 3669,
#    'site': 'youku.com',
#    'recordsCount': 94244880,
#    'description': 'Youku is a large Chinese video content company whose user database was allegedly breached in 2016. The compromised data later appeared for sale on a dark web marketplace April 2017. The dark web listing advertised the sale of 100M user accounts.',
#    'publishDate': '2017-03-24T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 94238535, 'emails': 94244880}},
#   '13094': {'breachId': 13094,
#    'site': 'myheritage.com',
#    'recordsCount': 110041653,
#    'description': 'In October 2017, a customer database belonging to online genealogy platform MyHeritage was breached. The stolen records included email addresses and SHA-1 hashed passwords, as well as sensitive PII. The data has been sold on at least one dark web market and is also being privately shared amongst several criminal groups.',
#    'publishDate': '2017-11-04T00:00:00Z',
#    'statistics': {'usernames': 0,
#     'passwords': 110041647,
#     'emails': 110041653}},
#   '13662': {'breachId': 13662,
#    'site': 'netlog.com',
#    'recordsCount': 52904632,
#    'description': 'Netlog (formerly known as Facebox and Bingbox) was a Belgian social networking website specifically targeted at the global youth demographic. On Netlog, members could create their own web page, meet new people, chat, play games, share videos and post blogs.\r\n\r\nIn July 2018, Netlog sent out an email informing users registered before December 2012 that there was a security breach of their user database.',
#    'publishDate': '2018-02-18T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 52902665, 'emails': 52904632}},
#   '16372': {'breachId': 16372,
#    'site': 'bookmate.com',
#    'recordsCount': 7775238,
#    'description': 'In July 2018, Bookmate was allegedly breached. The stolen data contains usernames, passwords, salts, email addresses and additional personal information. This data has been sold on at least one dark web market and is also being privately shared among several criminal networks.\r\n',
#    'publishDate': '2019-03-20T00:00:00Z',
#    'statistics': {'usernames': 7775230,
#     'passwords': 2547574,
#     'emails': 3822191}},
#   '16567': {'breachId': 16567,
#    'site': 'blankmediagames.com',
#    'recordsCount': 7767723,
#    'description': 'BlankMediaGames confirmed that it suffered a data breach impacting more than 7.6 million players of popular browser-based role playing game Town of Salem.  The exposed information includes usernames, email addresses, ip addresses, and passwords.  The data is being shared privately on the dark web.',
#    'publishDate': '2019-02-14T00:00:00Z',
#    'statistics': {'usernames': 7767701,
#     'passwords': 7767671,
#     'emails': 7757828}},
#   '16587': {'breachId': 16587,
#    'site': 'dubsmash.com',
#    'recordsCount': 161162574,
#    'description': "In December 2018, Dubsmash's database was allegedly breached. The stolen data contains usernames, passwords, email addresses and additional personal information. This breach is being privately shared on the internet.",
#    'publishDate': '2019-03-07T00:00:00Z',
#    'statistics': {'usernames': 159256428,
#     'passwords': 161154927,
#     'emails': 161146252}},
#   '16590': {'breachId': 16590,
#    'site': 'ixigo.com',
#    'recordsCount': 17229408,
#    'description': "At an unconfirmed date, Ixigo's database was allegedly breached. The stolen data contains usernames, passwords, email addresses and additional personal information. The data has been sold on at least one dark web market and is also being privately shared amongst several criminal groups.",
#    'publishDate': '2019-03-14T00:00:00Z',
#    'statistics': {'usernames': 7677264,
#     'passwords': 4001784,
#     'emails': 17190215}},
#   '16604': {'breachId': 16604,
#    'site': 'avvo.com',
#    'recordsCount': 5450710,
#    'description': "In May 2018, the legal marketplace Avvo's database was allegedly breached. The stolen data contains usernames, passwords, and email addresses. This breach is being privately shared on the internet.",
#    'publishDate': '2019-04-04T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 4543647, 'emails': 5450710}},
#   '16659': {'breachId': 16659,
#    'site': 'livejournal.com',
#    'recordsCount': 30485836,
#    'description': "In 2017, social network LiveJournal's database was allegedly breached. The stolen data contains passwords, email addresses and additional personal information. This breach is being privately shared in the dark web.",
#    'publishDate': '2019-05-23T00:00:00Z',
#    'statistics': {'usernames': 30485732,
#     'passwords': 29634403,
#     'emails': 30482018}},
#   '16665': {'breachId': 16665,
#    'site': 'shein.com',
#    'recordsCount': 41454777,
#    'description': "In June 2018, fast-fashion retailer Shein's database was allegedly breached. The stolen data contains passwords and email addresses. This breach is being privately shared on the internet.",
#    'publishDate': '2019-05-16T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 40976790, 'emails': 41454777}},
#   '16768': {'breachId': 16768,
#    'site': 'canva.com',
#    'recordsCount': 137434010,
#    'description': "In May 2019, graphic-design site Canva's database was allegedly breached. The stolen data contains usernames, passwords, email addresses and additional personal information. This breach is being privately shared on the internet.",
#    'publishDate': '2019-06-13T00:00:00Z',
#    'statistics': {'usernames': 137304104,
#     'passwords': 61348974,
#     'emails': 137402835}},
#   '16844': {'breachId': 16844,
#    'site': 'poshmark.com',
#    'recordsCount': 36121087,
#    'description': 'In May 2018, "gently-used" fashion retailer Poshmark\'s database was allegedly breached. The stolen data contains usernames, passwords, salts and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2019-08-08T00:00:00Z',
#    'statistics': {'usernames': 36120789,
#     'passwords': 33417000,
#     'emails': 36092399}},
#   '16868': {'breachId': 16868,
#    'site': 'borealis.su',
#    'recordsCount': 349061,
#    'description': "At an unconfirmed date, Russian Minecraft server Borealis.su's database was allegedly breached. The stolen data contains usernames, passwords, and email addresses. This breach is being privately shared on the internet.",
#    'publishDate': '2019-08-08T00:00:00Z',
#    'statistics': {'usernames': 349054, 'passwords': 349039, 'emails': 345545}},
#   '16935': {'breachId': 16935,
#    'site': 'xrumer.winguild.ru',
#    'recordsCount': 277201,
#    'description': "At an unconfirmed date, Russian audio equipment retailer Xrumer.Winguild.ru's database was allegedly breached. The stolen data contains passwords and email addresses. This breach is being publicly shared on the internet.",
#    'publishDate': '2019-09-12T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 275497, 'emails': 277201}},
#   '16962': {'breachId': 16962,
#    'site': 'cprewritten.net',
#    'recordsCount': 1687049,
#    'description': "In July 2019, virtual world Club Penguin Rewritten's database was allegedly breached. The stolen data contains usernames, passwords, email addresses and additional personal information. This breach is being publicly shared on the internet.",
#    'publishDate': '2019-09-26T00:00:00Z',
#    'statistics': {'usernames': 1687014,
#     'passwords': 1558530,
#     'emails': 1685691}},
#   '16982': {'breachId': 16982,
#    'site': 'ozonemc.ru',
#    'recordsCount': 1132757,
#    'description': 'At an unconfirmed date, two Russian Minecraft server databases (OzoneMC and FireMC) were allegedly breached. The stolen data contains usernames, IPs, passwords, email addresses and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2019-10-10T00:00:00Z',
#    'statistics': {'usernames': 1132752,
#     'passwords': 1132757,
#     'emails': 202211}},
#   '16985': {'breachId': 16985,
#    'site': 'minyanville.com',
#    'recordsCount': 64776,
#    'description': "At an unconfirmed date, Minyanville's database was allegedly breached. The stolen data contains passwords and email addresses. This breach is being privately shared on the internet.",
#    'publishDate': '2019-10-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 64764, 'emails': 64776}},
#   '17009': {'breachId': 17009,
#    'site': 'zynga.com',
#    'recordsCount': 216159495,
#    'description': 'In September 2019, the game developer Zynga was allegedly breached. The stolen data contains usernames, passwords, salts, email addresses and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2019-10-17T00:00:00Z',
#    'statistics': {'usernames': 214648143,
#     'passwords': 134762791,
#     'emails': 159032663}},
#   '17075': {'breachId': 17075,
#    'site': 'toondo.com',
#    'recordsCount': 6034161,
#    'description': 'In July 2019, the online comic creation site ToonDoo was allegedly breached. The stolen data contains usernames, IPs, passwords, salts, email addresses and additional personal information. This breach is being publicly shared on the internet.',
#    'publishDate': '2019-11-14T00:00:00Z',
#    'statistics': {'usernames': 6034158,
#     'passwords': 6034156,
#     'emails': 6024388}},
#   '17110': {'breachId': 17110,
#    'site': 'azcentral.com',
#    'recordsCount': 705538,
#    'description': 'At an unconfirmed date, online Arizona newspaper "AZ Central" was allegedly breached. The stolen data contains passwords and email addresses. This breach is being publicly shared on the internet.',
#    'publishDate': '2020-01-03T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 702971, 'emails': 705538}},
#   '17309': {'breachId': 17309,
#    'site': 'gogames.me',
#    'recordsCount': 2037975,
#    'description': 'In December 2019, the online mobile game GoGames was allegedly breached. The stolen data contains usernames, IPs, passwords, salts, email addresses and additional personal information. This breach is being publicly shared on the internet.',
#    'publishDate': '2020-01-16T00:00:00Z',
#    'statistics': {'usernames': 1708313,
#     'passwords': 2037975,
#     'emails': 2029863}},
#   '17312': {'breachId': 17312,
#    'site': 'cristalix.pe',
#    'recordsCount': 579672,
#    'description': 'In November 2019, the Russian Minecraft server Cristalix was allegedly breached. The stolen data contains usernames, IPs, passwords, email addresses and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2020-01-16T00:00:00Z',
#    'statistics': {'usernames': 579646, 'passwords': 579490, 'emails': 220827}},
#   '17313': {'breachId': 17313,
#    'site': 'paxful.com',
#    'recordsCount': 365406,
#    'description': "At an unconfirmed date, accounts belonging to the mobile cryptocurrency wallet Paxful were posted on a hacker forum. The leaked data contains passwords and email addresses. It's not clear if this data was the source of a breach, or from successful credential stuffing attempts.",
#    'publishDate': '2020-01-16T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 365249, 'emails': 365406}},
#   '17343': {'breachId': 17343,
#    'site': 'lekoolgames.com',
#    'recordsCount': 2525748,
#    'description': 'At an unconfirmed date, the online gaming site Lekool Games was allegedly breached. The stolen data contains passwords and email addresses. This breach is being publicly shared on the internet.',
#    'publishDate': '2020-01-30T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 2513972, 'emails': 2525748}},
#   '17363': {'breachId': 17363,
#    'site': 'shop.westwing.ru',
#    'recordsCount': 1572192,
#    'description': 'In November 2019, the Russian interior design Westwing Shop was allegedly breached. The stolen data contains passwords, email addresses and additional personal information. This breach is being publicly shared on the internet.',
#    'publishDate': '2020-02-20T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 1560850, 'emails': 1571986}},
#   '17370': {'breachId': 17370,
#    'site': 'excalibur-craft.ru',
#    'recordsCount': 1470812,
#    'description': 'At an unconfirmed date, the Russian Minecraft server Excaliburcraft was allegedly breached. The stolen data contains usernames and passwords. This breach is being privately shared on the internet.',
#    'publishDate': '2020-02-27T00:00:00Z',
#    'statistics': {'usernames': 1470809,
#     'passwords': 1192588,
#     'emails': 732539}},
#   '17433': {'breachId': 17433,
#    'site': 'romwe.com',
#    'recordsCount': 20310339,
#    'description': 'At an unconfirmed date, the online fashion retailer ROMWE was allegedly breached. The stolen data contains passwords and email addresses. This breach is being privately shared on the internet.',
#    'publishDate': '2020-04-02T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 17683990, 'emails': 20301726}},
#   '17457': {'breachId': 17457,
#    'site': 'vkmix.com',
#    'recordsCount': 2127865,
#    'description': 'At an unconfirmed date, the Russian social media sharing service VK Mix was allegedly breached. The stolen data contains passwords and email addresses. This breach is being privately shared on the internet.',
#    'publishDate': '2020-04-09T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 2127865, 'emails': 2127865}},
#   '17561': {'breachId': 17561,
#    'site': 'aptoide.com',
#    'recordsCount': 25285542,
#    'description': 'In April 2020, the software marketplace app Aptoide was allegedly breached. The stolen data contains usernames, passwords, IPs, email addresses and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2020-04-23T00:00:00Z',
#    'statistics': {'usernames': 19957710,
#     'passwords': 25278943,
#     'emails': 25282011}},
#   '17593': {'breachId': 17593,
#    'site': 'unacademy.com',
#    'recordsCount': 16267234,
#    'description': "In May 2020, the hacking group “ShinyHunters” claimed to have breached several companies and began selling their users' information on a dark web marketplace. One of their victims, the Indian online education platform Unacademy, was allegedly breached in January 2020 and was included in this list. The stolen data contains usernames, passwords, email addresses and additional personal information. This breach is being privately shared on the internet.  ",
#    'publishDate': '2020-05-14T00:00:00Z',
#    'statistics': {'usernames': 16257974,
#     'passwords': 16261767,
#     'emails': 11225021}},
#   '17605': {'breachId': 17605,
#    'site': 'www.joymax.com/silkroad/',
#    'recordsCount': 4562114,
#    'description': "In January 2012, the MMORPG game Silkroad Online's database was allegedly breached. The stolen data contains usernames, passwords, and email addresses. This breach is being privately shared on the internet.",
#    'publishDate': '2020-05-21T00:00:00Z',
#    'statistics': {'usernames': 4562114,
#     'passwords': 4559075,
#     'emails': 4463228}},
#   '17665': {'breachId': 17665,
#    'site': 'stalker.so',
#    'recordsCount': 1300204,
#    'description': 'In January 2020, the Russian multiplayer video game Stalker Online was allegedly breached. The stolen data contains usernames, IPs, passwords, and email addresses. This breach is being privately shared on the internet.',
#    'publishDate': '2020-05-28T00:00:00Z',
#    'statistics': {'usernames': 812994,
#     'passwords': 1300050,
#     'emails': 1298521}},
#   '17670': {'breachId': 17670,
#    'site': 'wishbone.io',
#    'recordsCount': 37475476,
#    'description': 'In January 2020, the online poll website Wishbone was allegedly breached. The stolen data contains usernames, passwords, email addresses and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2020-05-28T00:00:00Z',
#    'statistics': {'usernames': 31111127,
#     'passwords': 10648734,
#     'emails': 10234249}},
#   '17672': {'breachId': 17672,
#    'site': 'mathway.com',
#    'recordsCount': 25659943,
#    'description': 'In January 2020, the online math problem solving app Mathway was allegedly breached. The stolen data contains usernames, IPs, passwords, and email addresses. This breach is being privately shared on the internet.',
#    'publishDate': '2020-05-28T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 16868242, 'emails': 25657329}},
#   '17801': {'breachId': 17801,
#    'site': 'n/a/',
#    'recordsCount': 5436763,
#    'description': 'At an unconfirmed date, this Food Services Combo List was shared on a private forum. The proliferation of stolen or leaked databases has given rise to credential stuffing, a fairly simple technique in which criminals load lists of previously breached credentials (from Linkedin, MySpace, etc.), called combo lists, into automated brute-forcing tools to test credentials en masse.',
#    'publishDate': '2020-06-25T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 5428547, 'emails': 5436763}},
#   '17830': {'breachId': 17830,
#    'site': 'wattpad.com',
#    'recordsCount': 273322456,
#    'description': 'In June 2020, the online writing community Wattpad was allegedly breached. The stolen data contains usernames, IPs, passwords, email addresses and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2020-07-23T00:00:00Z',
#    'statistics': {'usernames': 270846321,
#     'passwords': 192540751,
#     'emails': 273004868}},
#   '17863': {'breachId': 17863,
#    'site': 'havenly.com',
#    'recordsCount': 1362159,
#    'description': 'In June 2020, the online interior design service Havenly was allegedly breached. The stolen data contains passwords, email addresses and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2020-08-06T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 1209583, 'emails': 1361967}},
#   '17884': {'breachId': 17884,
#    'site': 'aakash.ac.in',
#    'recordsCount': 1970402,
#    'description': 'At an unconfirmed date, the Indian online tutoring platform Aakash Institute was allegedly breached. The stolen data contains email addresses, passwords and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2020-08-20T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 1970402, 'emails': 1970402}},
#   '18122': {'breachId': 18122,
#    'site': 'vimeworld.ru',
#    'recordsCount': 12537602,
#    'description': 'In January 2018, the Russian Minecraft server VimeWorld was allegedly breached. The stolen data contains email addresses,  passwords and usernames. This breach is being privately shared on the internet.',
#    'publishDate': '2020-11-05T00:00:00Z',
#    'statistics': {'usernames': 9195268,
#     'passwords': 12530713,
#     'emails': 8517817}},
#   '18149': {'breachId': 18149,
#    'site': 'shopback.com',
#    'recordsCount': 20986635,
#    'description': 'In September 2020, the cashback reward program ShopBack was allegedly breached. The stolen data contains email addresses, passwords and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2020-11-19T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 13333031, 'emails': 20985037}},
#   '18158': {'breachId': 18158,
#    'site': 'redmart.lazada.sg',
#    'recordsCount': 1106408,
#    'description': 'At an unconfirmed date, the Singaporean online shop Redmart was allegedly breached. The stolen data contains passwords, email addresses, usernames and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2020-11-19T00:00:00Z',
#    'statistics': {'usernames': 261066,
#     'passwords': 1106408,
#     'emails': 1106335}},
#   '18413': {'breachId': 18413,
#    'site': 'ugmusic.net',
#    'recordsCount': 4769,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 4762, 'emails': 4769}},
#   '18998': {'breachId': 18998,
#    'site': 'xn--80asehdb.xn--80aeiluelyj.xn--p1ai',
#    'recordsCount': 40165,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 40156, 'emails': 40165}},
#   '20302': {'breachId': 20302,
#    'site': 'tendersinfo.com',
#    'recordsCount': 155756,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 153116, 'emails': 155756}},
#   '20492': {'breachId': 20492,
#    'site': 'beganwho.co.kr',
#    'recordsCount': 5489,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 5476, 'emails': 5489}},
#   '21433': {'breachId': 21433,
#    'site': 'grandevasion.ch',
#    'recordsCount': 15381,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 15381, 'emails': 15381}},
#   '21847': {'breachId': 21847,
#    'site': 'portal.gifteasycards.com',
#    'recordsCount': 1700,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 1700, 'emails': 1700}},
#   '22306': {'breachId': 22306,
#    'site': 'egrul-piter.ru',
#    'recordsCount': 193684,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-03T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 192290, 'emails': 193684}},
#   '22547': {'breachId': 22547,
#    'site': 'joplin.rhealana.com',
#    'recordsCount': 142213,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-03T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 141627, 'emails': 142213}},
#   '23281': {'breachId': 23281,
#    'site': 'xxx-igra.com',
#    'recordsCount': 30725,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 30683, 'emails': 30725}},
#   '23569': {'breachId': 23569,
#    'site': 'cbseguess.com',
#    'recordsCount': 172593,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-03T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 172020, 'emails': 172593}},
#   '23627': {'breachId': 23627,
#    'site': 'fpkp.ulsu.ru',
#    'recordsCount': 1937,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-03T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 1911, 'emails': 1937}},
#   '24208': {'breachId': 24208,
#    'site': 'akkord-avto.ru',
#    'recordsCount': 10807,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-03T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 10804, 'emails': 10807}},
#   '24295': {'breachId': 24295,
#    'site': 'altflot.ru',
#    'recordsCount': 10204,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-03T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 10201, 'emails': 10204}},
#   '24865': {'breachId': 24865,
#    'site': 'srv.testbag.com',
#    'recordsCount': 174144,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-03T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 173976, 'emails': 174144}},
#   '25112': {'breachId': 25112,
#    'site': 'tab.testbag.com',
#    'recordsCount': 262078,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-03T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 261781, 'emails': 262078}},
#   '25410': {'breachId': 25410,
#    'site': 'help.nevosoft.com',
#    'recordsCount': 791211,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 791015, 'emails': 791211}},
#   '25563': {'breachId': 25563,
#    'site': 'riatom.ru',
#    'recordsCount': 10999,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-03T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 10996, 'emails': 10999}},
#   '26430': {'breachId': 26430,
#    'site': 'spae.co.kr',
#    'recordsCount': 2414,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-03T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 2404, 'emails': 2414}},
#   '27151': {'breachId': 27151,
#    'site': 'rabota.bg',
#    'recordsCount': 152127,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 151404, 'emails': 152127}},
#   '27762': {'breachId': 27762,
#    'site': 'mindset24global.com',
#    'recordsCount': 395510,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-03T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 393394, 'emails': 395510}},
#   '28098': {'breachId': 28098,
#    'site': 'testbag.com',
#    'recordsCount': 192612,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-03T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 192593, 'emails': 192612}},
#   '28607': {'breachId': 28607,
#    'site': 'surveybasket.co.za',
#    'recordsCount': 10529,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-03T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 10529, 'emails': 10529}},
#   '28822': {'breachId': 28822,
#    'site': 'cie3secondes.com',
#    'recordsCount': 24737,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 24737, 'emails': 24737}},
#   '29141': {'breachId': 29141,
#    'site': 'hentaidub.ru',
#    'recordsCount': 33635,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 33571, 'emails': 33635}},
#   '29233': {'breachId': 29233,
#    'site': 'meetmaster.ru',
#    'recordsCount': 397347,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 397326, 'emails': 397347}},
#   '29929': {'breachId': 29929,
#    'site': 'eskuvoszombathely.hu',
#    'recordsCount': 60250,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 60250, 'emails': 60250}},
#   '29985': {'breachId': 29985,
#    'site': 'nunbab.co.kr',
#    'recordsCount': 5513,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 5506, 'emails': 5513}},
#   '30398': {'breachId': 30398,
#    'site': 'saleraja.com',
#    'recordsCount': 140564,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 140518, 'emails': 140564}},
#   '31355': {'breachId': 31355,
#    'site': 'botany.testbag.com',
#    'recordsCount': 243992,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-03T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 243742, 'emails': 243992}},
#   '31812': {'breachId': 31812,
#    'site': 'mindfiesta.com',
#    'recordsCount': 115539,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 114740, 'emails': 115539}},
#   '32154': {'breachId': 32154,
#    'site': 'ea-nhl.ru',
#    'recordsCount': 40570,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 40475, 'emails': 40570}},
#   '32532': {'breachId': 32532,
#    'site': 'amazepromos.com',
#    'recordsCount': 975954,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-10T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 975954, 'emails': 975954}},
#   '34081': {'breachId': 34081,
#    'site': 'rfinance.ru',
#    'recordsCount': 67526,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-17T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 67526, 'emails': 67526}},
#   '34564': {'breachId': 34564,
#    'site': 'address467.com',
#    'recordsCount': 5753,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-17T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 5746, 'emails': 5753}},
#   '35198': {'breachId': 35198,
#    'site': 'notes.fleita.com',
#    'recordsCount': 120084,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-17T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 119854, 'emails': 120084}},
#   '36490': {'breachId': 36490,
#    'site': 'intimkieva.com',
#    'recordsCount': 6827,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-17T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 6820, 'emails': 6827}},
#   '37030': {'breachId': 37030,
#    'site': 'forum.nedug.ru',
#    'recordsCount': 103754,
#    'description': 'In November 2020, a collection of over 23,000 breached sites was leaked on several hacking forums and Telegram channels. These breached sites originated from Cit0Day, a now-defunct private subscription service marketed towards criminals. The leaked data primarily includes email addresses and passwords that Cit0Day offered for a daily or monthly subscription fee.',
#    'publishDate': '2020-12-17T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 103190, 'emails': 103754}},
#   '37165': {'breachId': 37165,
#    'site': 'dfb.de',
#    'recordsCount': 19351508,
#    'description': 'In July 2016, the German Football Association (Deutscher Fußball-Bund) was allegedly breached. The stolen data contains email addresses and passwords. This breach is being privately shared on the internet.',
#    'publishDate': '2021-01-21T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 19044574, 'emails': 19351508}},
#   '37177': {'breachId': 37177,
#    'site': 'forums.vkmonline.com',
#    'recordsCount': 825654,
# ...
#    'recordsCount': 4771990,
#    'description': "The proliferation of stolen or leaked-breach databases has given rise to 'credential stuffing,' a fairly simple technique in which hackers load lists of stolen credentials (called combolists) into automated brute-force tools to test stolen passwords against thousands of other websites.",
#    'publishDate': '2021-07-15T00:00:00Z',
#    'statistics': {'usernames': 255666,
#     'passwords': 4758916,
#     'emails': 4517064}}},
#  'data': {'bookmate.com': {'kolya@mail.ru': [{'breachId': 16372,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'shopback.com': {'tanya@gmail.com': [{'breachId': 18149,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'invest.elevrus.com': {'tanya@gmail.com': [{'breachId': 37283,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'tendersinfo.com': {'tanya@gmail.com': [{'breachId': 20302,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'havenly.com': {'tanya@gmail.com': [{'breachId': 17863,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'hentaidub.ru': {'kolya@mail.ru': [{'breachId': 29141,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'jefit.com': {'kolya@mail.ru': [{'breachId': 37220,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'paxful.com': {'tanya@gmail.com': [{'breachId': 17313,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'unacademy.com': {'tanya@gmail.com': [{'breachId': 17593,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'parapa.mail.ru': {'xxx@x.ru': [{'breachId': 3176,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'cbseguess.com': {'tanya@gmail.com': [{'breachId': 23569,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'srv.testbag.com': {'tanya@gmail.com': [{'breachId': 24865,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'ugmusic.net': {'tanya@gmail.com': [{'breachId': 18413,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'forum.nedug.ru': {'tanya@gmail.com': [{'breachId': 37030,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'mindset24global.com': {'kolya@mail.ru': [{'breachId': 27762,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'shadowcraft.ru': {'kolya@mail.ru': [{'breachId': 37529,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'spae.co.kr': {'tanya@gmail.com': [{'breachId': 26430,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'minyanville.com': {'tanya@gmail.com': [{'breachId': 16985,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'blankmediagames.com': {'tanya@gmail.com': [{'breachId': 16567,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'borealis.su': {'kolya@mail.ru': [{'breachId': 16868,
#      'usernameBreached': True,
#      'passwordBreached': True}],
#    'vanya@yandex.ru': [{'breachId': 16868,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'mindfiesta.com': {'tanya@gmail.com': [{'breachId': 31812,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'riatom.ru': {'kolya@mail.ru': [{'breachId': 25563,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'wattpad.com': {'kolya@mail.ru': [{'breachId': 17830,
#      'usernameBreached': True,
#      'passwordBreached': True}],
#    'tanya@gmail.com': [{'breachId': 17830,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'adobe.com': {'yyy@y.com': [{'breachId': 3,
#      'usernameBreached': False,
#      'passwordBreached': True}],
#    'xxx@x.ru': [{'breachId': 3,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'grandevasion.ch': {'tanya@gmail.com': [{'breachId': 21433,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'joplin.rhealana.com': {'tanya@gmail.com': [{'breachId': 22547,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'rfinance.ru': {'kolya@mail.ru': [{'breachId': 34081,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'cdprojektred.com': {'xxx@x.ru': [{'breachId': 2961,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'notes.fleita.com': {'vanya@yandex.ru': [{'breachId': 35198,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'intimkieva.com': {'kolya@mail.ru': [{'breachId': 36490,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'cprewritten.net': {'tanya@gmail.com': [{'breachId': 16962,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'unknown': {'kolya@mail.ru': [{'breachId': 37777,
#      'usernameBreached': True,
#      'passwordBreached': True}],
#    'tanya@gmail.com': [{'breachId': 37785,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'xn--80asehdb.xn--80aeiluelyj.xn--p1ai': {'kolya@mail.ru': [{'breachId': 18998,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'ixigo.com': {'tanya@gmail.com': [{'breachId': 16590,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'dailyquiz.me': {'tanya@gmail.com': [{'breachId': 37570,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'nmmoney.xyz': {'tanya@gmail.com': [{'breachId': 37210,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'avvo.com': {'kolya@mail.ru': [{'breachId': 16604,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'portal.gifteasycards.com': {'tanya@gmail.com': [{'breachId': 21847,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'lekoolgames.com': {'tanya@gmail.com': [{'breachId': 17343,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'cristalix.pe': {'kolya@mail.ru': [{'breachId': 17312,
#      'usernameBreached': True,
#      'passwordBreached': True}],
#    'tanya@gmail.com': [{'breachId': 17312,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'aptoide.com': {'tanya@gmail.com': [{'breachId': 17561,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'azcentral.com': {'yyy@y.com': [{'breachId': 17110,
#      'usernameBreached': False,
#      'passwordBreached': True}],
#    'tanya@gmail.com': [{'breachId': 17110,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'poshmark.com': {'tanya@gmail.com': [{'breachId': 16844,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'linkedin.com': {'yyy@y.com': [{'breachId': 2,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'livejournal.com': {'kolya@mail.ru': [{'breachId': 16659,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'saleraja.com': {'tanya@gmail.com': [{'breachId': 30398,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'dropbox.com': {'yyy@y.com': [{'breachId': 41,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'xrumer.winguild.ru': {'kolya@mail.ru': [{'breachId': 16935,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'xxx-igra.com': {'kolya@mail.ru': [{'breachId': 23281,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'help.nevosoft.com': {'kolya@mail.ru': [{'breachId': 25410,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'wishbone.io': {'yyy@y.com': [{'breachId': 17670,
#      'usernameBreached': True,
#      'passwordBreached': True}],
#    'tanya@gmail.com': [{'breachId': 17670,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'vkmix.com': {'kolya@mail.ru': [{'breachId': 17457,
#      'usernameBreached': False,
#      'passwordBreached': True}],
#    'tanya@gmail.com': [{'breachId': 17457,
#      'usernameBreached': False,
#      'passwordBreached': True}],
#    'vanya@yandex.ru': [{'breachId': 17457,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'excalibur-craft.ru': {'kolya@mail.ru': [{'breachId': 17370,
#      'usernameBreached': True,
#      'passwordBreached': False}]},
#   'youku.com': {'yyy@y.com': [{'breachId': 3669,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'gogames.me': {'kolya@mail.ru': [{'breachId': 17309,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'akkord-avto.ru': {'kolya@mail.ru': [{'breachId': 24208,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'redmart.lazada.sg': {'tanya@gmail.com': [{'breachId': 18158,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'aakash.ac.in': {'tanya@gmail.com': [{'breachId': 17884,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'surveybasket.co.za': {'tanya@gmail.com': [{'breachId': 28607,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'bookchor.com': {'tanya@gmail.com': [{'breachId': 37382,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'testbag.com': {'tanya@gmail.com': [{'breachId': 28098,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'myheritage.com': {'yyy@y.com': [{'breachId': 13094,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'egrul-piter.ru': {'kolya@mail.ru': [{'breachId': 22306,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'beganwho.co.kr': {'tanya@gmail.com': [{'breachId': 20492,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'dubsmash.com': {'kolya@mail.ru': [{'breachId': 16587,
#      'usernameBreached': True,
#      'passwordBreached': True}],
#    'tanya@gmail.com': [{'breachId': 16587,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'rayli.com.cn': {'yyy@y.com': [{'breachId': 3587,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'www.joymax.com/silkroad/': {'kolya@mail.ru': [{'breachId': 17605,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'canva.com': {'yyy@y.com': [{'breachId': 16768,
#      'usernameBreached': True,
#      'passwordBreached': True}],
#    'kolya@mail.ru': [{'breachId': 16768,
#      'usernameBreached': True,
#      'passwordBreached': True}],
#    'tanya@gmail.com': [{'breachId': 16768,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'vimeworld.ru': {'kolya@mail.ru': [{'breachId': 18122,
#      'usernameBreached': True,
#      'passwordBreached': True}],
#    'tanya@gmail.com': [{'breachId': 18122,
#      'usernameBreached': True,
#      'passwordBreached': True}],
#    'vanya@yandex.ru': [{'breachId': 18122,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'fpkp.ulsu.ru': {'kolya@mail.ru': [{'breachId': 23627,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'tab.testbag.com': {'tanya@gmail.com': [{'breachId': 25112,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'dfb.de': {'tanya@gmail.com': [{'breachId': 37165,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'globalreach.eu': {'yyy@y.com': [{'breachId': 3520,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'rabota.bg': {'kolya@mail.ru': [{'breachId': 27151,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'altflot.ru': {'kolya@mail.ru': [{'breachId': 24295,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'cfire.mail.ru': {'xxx@x.ru': [{'breachId': 3164,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'vk.com': {'xxx@x.ru': [{'breachId': 12,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'eskuvoszombathely.hu': {'tanya@gmail.com': [{'breachId': 29929,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'forums.vkmonline.com': {'yyy@y.com': [{'breachId': 37177,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'bigbasket.com': {'tanya@gmail.com': [{'breachId': 37446,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'ea-nhl.ru': {'kolya@mail.ru': [{'breachId': 32154,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'stalker.so': {'kolya@mail.ru': [{'breachId': 17665,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'address467.com': {'tanya@gmail.com': [{'breachId': 34564,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'meetmaster.ru': {'kolya@mail.ru': [{'breachId': 29233,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'n/a/': {'kolya@mail.ru': [{'breachId': 17801,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'amazepromos.com': {'tanya@gmail.com': [{'breachId': 32532,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'mathway.com': {'tanya@gmail.com': [{'breachId': 17672,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'netlog.com': {'yyy@y.com': [{'breachId': 13662,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'romwe.com': {'tanya@gmail.com': [{'breachId': 17433,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'shop.westwing.ru': {'tanya@gmail.com': [{'breachId': 17363,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'ozonemc.ru': {'kolya@mail.ru': [{'breachId': 16982,
#      'usernameBreached': True,
#      'passwordBreached': True}],
#    'tanya@gmail.com': [{'breachId': 16982,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'nunbab.co.kr': {'tanya@gmail.com': [{'breachId': 29985,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'imesh.com': {'yyy@y.com': [{'breachId': 15,
#      'usernameBreached': True,
#      'passwordBreached': True}],
#    'xxx@x.ru': [{'breachId': 15,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'shein.com': {'tanya@gmail.com': [{'breachId': 16665,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'botany.testbag.com': {'tanya@gmail.com': [{'breachId': 31355,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'zynga.com': {'yyy@y.com': [{'breachId': 17009,
#      'usernameBreached': True,
#      'passwordBreached': False}],
#    'kolya@mail.ru': [{'breachId': 17009,
#      'usernameBreached': True,
#      'passwordBreached': True}],
#    'tanya@gmail.com': [{'breachId': 17009,
#      'usernameBreached': True,
#      'passwordBreached': False}]},
#   'toondo.com': {'kolya@mail.ru': [{'breachId': 17075,
#      'usernameBreached': True,
#      'passwordBreached': True}],
#    'tanya@gmail.com': [{'breachId': 17075,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'cie3secondes.com': {'kolya@mail.ru': [{'breachId': 28822,
#      'usernameBreached': False,
#      'passwordBreached': True}]}},
#  'summary': {'yyy@y.com': {'breaches': [2,
#     3,
#     15,
#     41,
#     3520,
#     3587,
#     3669,
#     13094,
#     13662,
#     16768,
#     17009,
#     17110,
#     17670,
#     37177]},
#   'xxx@x.ru': {'breaches': [3, 12, 15, 2961, 3164, 3176]},
#   'kolya@mail.ru': {'breaches': [16372,
#     16587,
#     16604,
#     16659,
#     16768,
#     16868,
#     16935,
#     16982,
#     17009,
#     17075,
#     17309,
#     17312,
#     17370,
#     17457,
#     17605,
#     17665,
#     17801,
#     17830,
#     18122,
#     18998,
#     22306,
#     23281,
#     23627,
#     24208,
#     24295,
#     25410,
#     25563,
#     27151,
#     27762,
#     28822,
#     29141,
#     29233,
#     32154,
#     34081,
#     36490,
#     37220,
#     37529,
#     37777]},
#   'tanya@gmail.com': {'breaches': [16567,
#     16587,
#     16590,
#     16665,
#     16768,
#     16844,
#     16962,
#     16982,
#     16985,
#     17009,
#     17075,
#     17110,
#     17312,
#     17313,
#     17343,
#     17363,
#     17433,
#     17457,
#     17561,
#     17593,
#     17670,
#     17672,
#     17830,
#     17863,
#     17884,
#     18122,
#     18149,
#     18158,
#     18413,
#     20302,
#     20492,
#     21433,
#     21847,
#     22547,
#     23569,
#     24865,
#     25112,
#     26430,
#     28098,
#     28607,
#     29929,
#     29985,
#     30398,
#     31355,
#     31812,
#     32532,
#     34564,
#     37030,
#     37165,
#     37210,
#     37283,
#     37382,
#     37446,
#     37570,
#     37785]},
#   'vanya@yandex.ru': {'breaches': [16868, 17457, 18122, 35198]}}}

# %%
# по заданию должен формироваться датафрейм со столбцами: <дата утечки> - <источник утечки> - <описание утечки>
# не лишним будет также указывать и почту, для которой произошла утечка. У каждого события утечки есть свой номер - breachId
# сопоставим емэйл адрес и события утечки
email_id = pd.DataFrame()
for mail, breaches in r.json()['summary'].items():
    for breachId in breaches['breaches']:
#         print(breachId)
        row  = {'email': mail, 'breachId': int(breachId)}
        email_id = pd.concat([email_id, pd.DataFrame([row])], ignore_index=True)

email_id
# Out:
#                email  breachId
# 0          yyy@y.com         2
# 1          yyy@y.com         3
# 2          yyy@y.com        15
# 3          yyy@y.com        41
# 4          yyy@y.com      3520
# ..               ...       ...
# 112  tanya@gmail.com     37785
# 113  vanya@yandex.ru     16868
# 114  vanya@yandex.ru     17457
# 115  vanya@yandex.ru     18122
# 116  vanya@yandex.ru     35198
#
# [117 rows x 2 columns]

# %%
# подготовим датафрейм с подробными сведениями по каждой утечке данных
email_dframe = pd.DataFrame()
for breachId, event in r.json()['breaches'].items():
    row = {
        'breachId': int(breachId), 
        'Дата утечки': pd.to_datetime(event['publishDate']).date(), 
        'Источник утечки': event['site'], 
        'Описание утечки': event['description']}
    email_dframe = pd.concat([email_dframe, pd.DataFrame([row])], ignore_index=True)
email_dframe
# Out:
#     breachId Дата утечки Источник утечки  \
# 0          2  2016-10-21    linkedin.com
# 1          3  2016-10-21       adobe.com
# 2         12  2016-10-29          vk.com
# 3         15  2016-10-23       imesh.com
# 4         41  2016-10-24     dropbox.com
# ..       ...         ...             ...
# 94     37446  2021-04-29   bigbasket.com
# 95     37529  2021-05-27  shadowcraft.ru
# 96     37570  2021-05-27    dailyquiz.me
# 97     37777  2021-07-15         unknown
# 98     37785  2021-07-15         unknown
#
#                                       Описание утечки
# 0   In 2012, online professional networking platfo...
# 1   In October of 2013, criminals penetrated Adobe...
# 2   Popular Russian social networking platform VKo...
# 3   In June 2016, a cache of over 51 million user ...
# 4   Cloud storage company Dropbox suffered a major...
# ..                                                ...
# 94  In October 2020, the Indian online grocery sto...
# 95  At an unknown date, the Russian Minecraft serv...
# 96  In January 2021, the entertainment website Dai...
# 97  In June 2021, data from an unknown Russian tec...
# 98  The proliferation of stolen or leaked-breach d...
#
# [99 rows x 4 columns]

# %%
# получил разное количество строк в датафреймах email_dframe и email_id - это из-за того, что каждому событию утечки breachId
# можно соотнести несколько почтовых адресов. Чтобы убедиться, что количеситво уникальных breachId в обоих датафремах
# одинаково, удалю дублирующиеся
email_id.drop_duplicates(subset='breachId', ignore_index=True)
# Out:
#               email  breachId
# 0         yyy@y.com         2
# 1         yyy@y.com         3
# 2         yyy@y.com        15
# 3         yyy@y.com        41
# 4         yyy@y.com      3520
# ..              ...       ...
# 94  tanya@gmail.com     37382
# 95  tanya@gmail.com     37446
# 96  tanya@gmail.com     37570
# 97  tanya@gmail.com     37785
# 98  vanya@yandex.ru     35198
#
# [99 rows x 2 columns]

# %%
# т.о. в обоих датафреймах имеется одинаковые множества breachId. Можно без потери данных объеденить датафреймы по этому столбцу
total_result = email_id.merge(email_dframe, how = 'outer', on = 'breachId')
#pd.set_option('display.max_rows', None)   - можно разкомментировать чтобы отключить ограничение на количество выводимых строк 
print('Итоговый датафрейм: ')
total_result
# Out:
# Итоговый датафрейм:
#                email  breachId Дата утечки   Источник утечки  \
# 0          yyy@y.com         2  2016-10-21      linkedin.com
# 1          yyy@y.com         3  2016-10-21         adobe.com
# 2           xxx@x.ru         3  2016-10-21         adobe.com
# 3          yyy@y.com        15  2016-10-23         imesh.com
# 4           xxx@x.ru        15  2016-10-23         imesh.com
# ..               ...       ...         ...               ...
# 112  tanya@gmail.com     37382  2021-04-22      bookchor.com
# 113  tanya@gmail.com     37446  2021-04-29     bigbasket.com
# 114  tanya@gmail.com     37570  2021-05-27      dailyquiz.me
# 115  tanya@gmail.com     37785  2021-07-15           unknown
# 116  vanya@yandex.ru     35198  2020-12-17  notes.fleita.com
#
#                                        Описание утечки
# 0    In 2012, online professional networking platfo...
# 1    In October of 2013, criminals penetrated Adobe...
# 2    In October of 2013, criminals penetrated Adobe...
# 3    In June 2016, a cache of over 51 million user ...
# 4    In June 2016, a cache of over 51 million user ...
# ..                                                 ...
# 112  In February 2021, the online second-hand books...
# 113  In October 2020, the Indian online grocery sto...
# 114  In January 2021, the entertainment website Dai...
# 115  The proliferation of stolen or leaked-breach d...
# 116  In November 2020, a collection of over 23,000 ...
#
# [117 rows x 5 columns]

# %% [markdown]
# ## Дополнительная часть (необязательная)

# %% [markdown]
# Написать скрипт, который будет получать 50 последних постов указанной группы во Вконтакте.
# Документация к API VK: https://vk.com/dev/methods , вам поможет метод wall.get
#
# GROUP = 'netology'
#
# TOKEN = УДАЛЯЙТЕ В ВЕРСИИ ДЛЯ ПРОВЕРКИ, НА GITHUB НЕ ВЫКЛАДЫВАТЬ
#
# В итоге должен формироваться датафрейм со столбцами: <дата поста> - <текст поста>

# %%
# задаем параметры для запроса к методу wall.get
TOKEN = 'беспорядочныйнаборцифрибукв'
URL_REQUEST = 'https://api.vk.com/method/wall.get?'
GROUP = 'netology'
VERSION = '5.131'
params = {
    'domain': GROUP,
    'access_token': TOKEN,
    'v': VERSION,
    'count': 50
}

# %%
res = requests.get(URL_REQUEST, params) # Сам запрос

# %%
import datetime
D_frame=pd.DataFrame(res.json()['response']['items']) # Получаем полный датафрейм с сообщениями на стене сообщества
D_frame['date'] = pd.to_datetime(D_frame['date'], unit='s').dt.date # Преобразуем дату в человеческий вид
D_frame
# Out:
#        id   from_id  owner_id        date  marked_as_ads post_type  \
# 0   94620 -30159897 -30159897  2021-08-16              0      post
# 1   97232 -30159897 -30159897  2021-08-19              0      post
# 2   96837 -30159897 -30159897  2021-08-18              0      post
# 3   96438 -30159897 -30159897  2021-08-18              0      post
# 4   95022 -30159897 -30159897  2021-08-17              0      post
# 5   94714 -30159897 -30159897  2021-08-17              0      post
# 6   94662 -30159897 -30159897  2021-08-16              0      post
# 7   94610 -30159897 -30159897  2021-08-16              0      post
# 8   94583 -30159897 -30159897  2021-08-15              0      post
# 9   94554 -30159897 -30159897  2021-08-14              0      post
# 10  94524 -30159897 -30159897  2021-08-13              0      post
# 11  94491 -30159897 -30159897  2021-08-13              0      post
# 12  94370 -30159897 -30159897  2021-08-12              0      post
# 13  94354 -30159897 -30159897  2021-08-12              0      post
# 14  94032 -30159897 -30159897  2021-08-11              0      post
# 15  94009 -30159897 -30159897  2021-08-11              0      post
# 16  93985 -30159897 -30159897  2021-08-10              0      post
# 17  93951 -30159897 -30159897  2021-08-10              0      post
# 18  93939 -30159897 -30159897  2021-08-09              0      post
# 19  93918 -30159897 -30159897  2021-08-09              0      post
# 20  93818 -30159897 -30159897  2021-08-09              0      post
# 21  93798 -30159897 -30159897  2021-08-08              0      post
# 22  93750 -30159897 -30159897  2021-08-08              0      post
# 23  93747 -30159897 -30159897  2021-08-07              0      post
# 24  93744 -30159897 -30159897  2021-08-07              0      post
# 25  93714 -30159897 -30159897  2021-08-06              0      post
# 26  93700 -30159897 -30159897  2021-08-06              0      post
# 27  93688 -30159897 -30159897  2021-08-05              0      post
# 28  93650 -30159897 -30159897  2021-08-05              0      post
# 29  93632 -30159897 -30159897  2021-08-05              0      post
# 30  93353 -30159897 -30159897  2021-08-04              0      post
# 31  93333 -30159897 -30159897  2021-08-04              0      post
# 32  93313 -30159897 -30159897  2021-08-03              0      post
# 33  93298 -30159897 -30159897  2021-08-03              0      post
# 34  93292 -30159897 -30159897  2021-08-02              0      post
# 35  93284 -30159897 -30159897  2021-08-02              0      post
# 36  93283 -30159897 -30159897  2021-08-02              0      post
# 37  93282 -30159897 -30159897  2021-08-01              0      post
# 38  93277 -30159897 -30159897  2021-08-01              0      post
# 39  93272 -30159897 -30159897  2021-07-31              0      post
# 40  93266 -30159897 -30159897  2021-07-30              0      post
# 41  93257 -30159897 -30159897  2021-07-30              0      post
# 42  93244 -30159897 -30159897  2021-07-29              0      post
# 43  93241 -30159897 -30159897  2021-07-29              0      post
# 44  93232 -30159897 -30159897  2021-07-28              0      post
# 45  93228 -30159897 -30159897  2021-07-28              0      post
# 46  93213 -30159897 -30159897  2021-07-27              0      post
# 47  93207 -30159897 -30159897  2021-07-27              0      post
# 48  93203 -30159897 -30159897  2021-07-26              0      post
# 49  93199 -30159897 -30159897  2021-07-26              0      post
#
#                                                  text  is_pinned  \
# 0   Наш летний диджитал-марафон продолжается 🎁\n \...        1.0
# 1   С появлением искусственного интеллекта тратить...        NaN
# 2   У нас сегодня Нето-викторина 🤩\n\nМы подготови...        NaN
# 3   Запустили курс «Старт в SMM» 🙃\n \nSMM-специал...        NaN
# 4   Вебинар ничем не отличается от любого публично...        NaN
# 5   💼 20 августа в 19:00 на нашем Ютуб-канале прой...        NaN
# 6   Коллаборации с блогерами — один из важных инст...        NaN
# 7   25 августа стартует бесплатный курс «Системный...        NaN
# 8   Ещё немного и лето закончится 🙁 \n \nПредлагае...        NaN
# 9   Летний отпуск может серьёзно ударить по карман...        NaN
# 10  Конец лета уже совсем близко, надеемся, что вы...        NaN
# 11  Как придумывать хорошие заголовки, делать стор...        NaN
# 12  Коммуникабельность, ответственность — это, кон...        NaN
# 13  Современный голосовой ассистент — это реалисти...        NaN
# 14  У нас сегодня Нето-викторина 🤩\n\nМы подготови...        NaN
# 15  Запустили бесплатный курс «Введение в геймдиза...        NaN
# 16  Купите слона! 🐘 \n \nРассказываем, как с помощ...        NaN
# 17  Профессия финансиста неоднородна: существуют р...        NaN
# 18  Выкладывать видео в ТикТок и просто надеяться,...        NaN
# 19  Наш летний диджитал-марафон продолжается 🎁\n \...        NaN
# 20  17 августа стартует бесплатный курс «Первые ша...        NaN
# 21  *партнёрский пост*\n\nКаждый четвёртый выпускн...        NaN
# 22  Мы очень мало знаем о своём мозге 🤯 \nНескольк...        NaN
# 23  Мы часто делимся историями роста наших студент...        NaN
# 24  Мечтаете попасть в реки? 🤪 \n \nСобрали статьи...        NaN
# 25  📅 Составляем список дел до конца лета \n \nДо ...        NaN
# 26  Аналитика не такая сложная, если в ней начать ...        NaN
# 27  Доброго времени суток! 😊 \n \nРассказываем, ка...        NaN
# 28  Перемены бывают в жизни каждого из нас: сменит...        NaN
# 29  Берём любимые снеки и идём смотреть новый роли...        NaN
# 30  У нас сегодня Нето-викторина 🤩\n\nМы подготови...        NaN
# 31  💼 16 августа стартует курс «Как стать продакт-...        NaN
# 32  Что делать, если хочется сменить профессию, но...        NaN
# 33  Сильные тексты важны как в маркетинге, так и в...        NaN
# 34  Популярность софт скилов растёт, потому что эт...        NaN
# 35  Лето в самом разгаре и мы надеемся, что вы не ...        NaN
# 36  Залетаем в реки с нашим бесплатным курсом «Про...        NaN
# 37  Рынок образования претерпел серьёзные изменени...        NaN
# 38  Учиться тоже нужно уметь 🤔 \n \nСобрали книги,...        NaN
# 39  У диджитал-профессий есть свои особенности, о ...        NaN
# 40  Компьютеры появились ещё в прошлом столетии, н...        NaN
# 41  В конце каждого месяца заботливо собираем подб...        NaN
# 42  Работа в диджитал ≠ лежать под пальмой где-ниб...        NaN
# 43  Продолжаем снимать новый формат видео, в котор...        NaN
# 44  Ещё несколько дней и начнётся последний месяц ...        NaN
# 45  👩‍🎨 Запустили бесплатный курс «Как стать дизай...        NaN
# 46  Когда действительно любишь работу, часто бывае...        NaN
# 47  Куда развивать стартап — отвечает предпринимат...        NaN
# 48  Написали конспект по открытой лекции «Как учит...        NaN
# 49  Запустили бесплатный курс «Основы интернет-мар...        NaN
#
#                                           attachments      post_source  \
# 0   [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 1   [{'type': 'link', 'link': {'url': 'http://neto...   {'type': 'vk'}
# 2   [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'api'}
# 3   [{'type': 'link', 'link': {'url': 'http://neto...   {'type': 'vk'}
# 4   [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 5   [{'type': 'link', 'link': {'url': 'http://neto...   {'type': 'vk'}
# 6   [{'type': 'link', 'link': {'url': 'http://neto...   {'type': 'vk'}
# 7   [{'type': 'link', 'link': {'url': 'http://neto...   {'type': 'vk'}
# 8   [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 9   [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 10  [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 11  [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 12  [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 13  [{'type': 'link', 'link': {'url': 'http://neto...   {'type': 'vk'}
# 14  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'api'}
# 15  [{'type': 'link', 'link': {'url': 'http://neto...   {'type': 'vk'}
# 16  [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 17  [{'type': 'link', 'link': {'url': 'http://neto...   {'type': 'vk'}
# 18  [{'type': 'link', 'link': {'url': 'http://neto...   {'type': 'vk'}
# 19  [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 20  [{'type': 'link', 'link': {'url': 'http://neto...   {'type': 'vk'}
# 21  [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 22  [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 23  [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 24  [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 25  [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 26  [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 27  [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 28  [{'type': 'link', 'link': {'url': 'http://neto...   {'type': 'vk'}
# 29  [{'type': 'link', 'link': {'url': 'http://neto...   {'type': 'vk'}
# 30  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'api'}
# 31  [{'type': 'link', 'link': {'url': 'http://neto...   {'type': 'vk'}
# 32  [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 33  [{'type': 'link', 'link': {'url': 'http://neto...   {'type': 'vk'}
# 34  [{'type': 'link', 'link': {'url': 'http://neto...   {'type': 'vk'}
# 35  [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 36  [{'type': 'link', 'link': {'url': 'http://neto...   {'type': 'vk'}
# 37  [{'type': 'link', 'link': {'url': 'http://neto...   {'type': 'vk'}
# 38  [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 39  [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 40  [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 41  [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 42  [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 43  [{'type': 'link', 'link': {'url': 'http://neto...   {'type': 'vk'}
# 44  [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 45  [{'type': 'link', 'link': {'url': 'http://neto...   {'type': 'vk'}
# 46  [{'type': 'photo', 'photo': {'album_id': -7, '...   {'type': 'vk'}
# 47  [{'type': 'link', 'link': {'url': 'http://neto...   {'type': 'vk'}
# 48  [{'type': 'link', 'link': {'url': 'http://neto...   {'type': 'vk'}
# 49  [{'type': 'link', 'link': {'url': 'http://neto...   {'type': 'vk'}
#
#                                              comments  \
# 0   {'count': 139, 'can_post': 1, 'groups_can_post...
# 1   {'count': 60, 'can_post': 1, 'groups_can_post'...
# 2   {'count': 393, 'can_post': 1, 'groups_can_post...
# 3   {'count': 327, 'can_post': 1, 'groups_can_post...
# 4   {'count': 791, 'can_post': 1, 'groups_can_post...
# 5   {'count': 203, 'can_post': 1, 'groups_can_post...
# 6   {'count': 45, 'can_post': 1, 'groups_can_post'...
# 7   {'count': 16, 'can_post': 1, 'groups_can_post'...
# 8   {'count': 74, 'can_post': 1, 'groups_can_post'...
# 9   {'count': 156, 'can_post': 1, 'groups_can_post...
# 10  {'count': 102, 'can_post': 1, 'groups_can_post...
# 11  {'count': 18, 'can_post': 1, 'groups_can_post'...
# 12  {'count': 66, 'can_post': 1, 'groups_can_post'...
# 13  {'count': 186, 'can_post': 1, 'groups_can_post...
# 14  {'count': 420, 'can_post': 1, 'groups_can_post...
# 15  {'count': 13, 'can_post': 1, 'groups_can_post'...
# 16  {'count': 11, 'can_post': 1, 'groups_can_post'...
# 17  {'count': 8, 'can_post': 1, 'groups_can_post':...
# 18  {'count': 14, 'can_post': 1, 'groups_can_post'...
# 19  {'count': 19, 'can_post': 1, 'groups_can_post'...
# 20  {'count': 27, 'can_post': 1, 'groups_can_post'...
# 21  {'count': 17, 'can_post': 1, 'groups_can_post'...
# 22  {'count': 11, 'can_post': 1, 'groups_can_post'...
# 23  {'count': 12, 'can_post': 1, 'groups_can_post'...
# 24  {'count': 9, 'can_post': 1, 'groups_can_post':...
# 25  {'count': 20, 'can_post': 1, 'groups_can_post'...
# 26  {'count': 9, 'can_post': 1, 'groups_can_post':...
# 27  {'count': 13, 'can_post': 1, 'groups_can_post'...
# 28  {'count': 7, 'can_post': 1, 'groups_can_post':...
# 29  {'count': 10, 'can_post': 1, 'groups_can_post'...
# 30  {'count': 378, 'can_post': 1, 'groups_can_post...
# 31  {'count': 18, 'can_post': 1, 'groups_can_post'...
# 32  {'count': 30, 'can_post': 1, 'groups_can_post'...
# 33  {'count': 17, 'can_post': 1, 'groups_can_post'...
# 34  {'count': 13, 'can_post': 1, 'groups_can_post'...
# 35  {'count': 13, 'can_post': 1, 'groups_can_post'...
# 36  {'count': 9, 'can_post': 1, 'groups_can_post':...
# 37  {'count': 9, 'can_post': 1, 'groups_can_post':...
# 38  {'count': 8, 'can_post': 1, 'groups_can_post':...
# 39  {'count': 0, 'can_post': 1, 'groups_can_post':...
# 40  {'count': 15, 'can_post': 1, 'groups_can_post'...
# 41  {'count': 0, 'can_post': 1, 'groups_can_post':...
# 42  {'count': 1, 'can_post': 1, 'groups_can_post':...
# 43  {'count': 0, 'can_post': 1, 'groups_can_post':...
# 44  {'count': 4, 'can_post': 1, 'groups_can_post':...
# 45  {'count': 0, 'can_post': 1, 'groups_can_post':...
# 46  {'count': 0, 'can_post': 1, 'groups_can_post':...
# 47  {'count': 0, 'can_post': 1, 'groups_can_post':...
# 48  {'count': 0, 'can_post': 1, 'groups_can_post':...
# 49  {'count': 0, 'can_post': 1, 'groups_can_post':...
#
#                                                 likes  \
# 0   {'count': 28, 'user_likes': 0, 'can_like': 1, ...
# 1   {'count': 18, 'user_likes': 0, 'can_like': 1, ...
# 2   {'count': 15, 'user_likes': 0, 'can_like': 1, ...
# 3   {'count': 29, 'user_likes': 0, 'can_like': 1, ...
# 4   {'count': 51, 'user_likes': 0, 'can_like': 1, ...
# 5   {'count': 28, 'user_likes': 0, 'can_like': 1, ...
# 6   {'count': 31, 'user_likes': 0, 'can_like': 1, ...
# 7   {'count': 28, 'user_likes': 0, 'can_like': 1, ...
# 8   {'count': 74, 'user_likes': 0, 'can_like': 1, ...
# 9   {'count': 37, 'user_likes': 0, 'can_like': 1, ...
# 10  {'count': 37, 'user_likes': 0, 'can_like': 1, ...
# 11  {'count': 32, 'user_likes': 0, 'can_like': 1, ...
# 12  {'count': 74, 'user_likes': 0, 'can_like': 1, ...
# 13  {'count': 18, 'user_likes': 0, 'can_like': 1, ...
# 14  {'count': 30, 'user_likes': 0, 'can_like': 1, ...
# 15  {'count': 39, 'user_likes': 0, 'can_like': 1, ...
# 16  {'count': 43, 'user_likes': 0, 'can_like': 1, ...
# 17  {'count': 26, 'user_likes': 0, 'can_like': 1, ...
# 18  {'count': 37, 'user_likes': 0, 'can_like': 1, ...
# 19  {'count': 29, 'user_likes': 0, 'can_like': 1, ...
# 20  {'count': 34, 'user_likes': 0, 'can_like': 1, ...
# 21  {'count': 18, 'user_likes': 0, 'can_like': 1, ...
# 22  {'count': 44, 'user_likes': 0, 'can_like': 1, ...
# 23  {'count': 20, 'user_likes': 0, 'can_like': 1, ...
# 24  {'count': 35, 'user_likes': 0, 'can_like': 1, ...
# 25  {'count': 24, 'user_likes': 0, 'can_like': 1, ...
# 26  {'count': 41, 'user_likes': 0, 'can_like': 1, ...
# 27  {'count': 41, 'user_likes': 0, 'can_like': 1, ...
# 28  {'count': 35, 'user_likes': 0, 'can_like': 1, ...
# 29  {'count': 19, 'user_likes': 0, 'can_like': 1, ...
# 30  {'count': 19, 'user_likes': 0, 'can_like': 1, ...
# 31  {'count': 27, 'user_likes': 0, 'can_like': 1, ...
# 32  {'count': 54, 'user_likes': 0, 'can_like': 1, ...
# 33  {'count': 51, 'user_likes': 0, 'can_like': 1, ...
# 34  {'count': 34, 'user_likes': 0, 'can_like': 1, ...
# 35  {'count': 36, 'user_likes': 0, 'can_like': 1, ...
# 36  {'count': 28, 'user_likes': 0, 'can_like': 1, ...
# 37  {'count': 20, 'user_likes': 0, 'can_like': 1, ...
# 38  {'count': 80, 'user_likes': 0, 'can_like': 1, ...
# 39  {'count': 27, 'user_likes': 0, 'can_like': 1, ...
# 40  {'count': 16, 'user_likes': 0, 'can_like': 1, ...
# 41  {'count': 40, 'user_likes': 0, 'can_like': 1, ...
# 42  {'count': 111, 'user_likes': 0, 'can_like': 1,...
# 43  {'count': 10, 'user_likes': 0, 'can_like': 1, ...
# 44  {'count': 72, 'user_likes': 0, 'can_like': 1, ...
# 45  {'count': 21, 'user_likes': 0, 'can_like': 1, ...
# 46  {'count': 139, 'user_likes': 0, 'can_like': 1,...
# 47  {'count': 12, 'user_likes': 0, 'can_like': 1, ...
# 48  {'count': 21, 'user_likes': 0, 'can_like': 1, ...
# 49  {'count': 23, 'user_likes': 0, 'can_like': 1, ...
#
#                                reposts              views  is_favorite  \
# 0     {'count': 2, 'user_reposted': 0}    {'count': 2824}        False
# 1     {'count': 1, 'user_reposted': 0}    {'count': 1096}        False
# 2     {'count': 0, 'user_reposted': 0}    {'count': 1524}        False
# 3    {'count': 10, 'user_reposted': 0}   {'count': 33165}        False
# 4    {'count': 33, 'user_reposted': 0}   {'count': 13400}        False
# 5     {'count': 1, 'user_reposted': 0}   {'count': 33614}        False
# 6    {'count': 13, 'user_reposted': 0}   {'count': 16402}        False
# 7     {'count': 9, 'user_reposted': 0}   {'count': 72820}        False
# 8    {'count': 50, 'user_reposted': 0}   {'count': 23503}        False
# 9    {'count': 10, 'user_reposted': 0}   {'count': 60145}        False
# 10   {'count': 19, 'user_reposted': 0}   {'count': 14757}        False
# 11   {'count': 18, 'user_reposted': 0}    {'count': 3622}        False
# 12   {'count': 43, 'user_reposted': 0}   {'count': 57517}        False
# 13    {'count': 2, 'user_reposted': 0}    {'count': 2160}        False
# 14    {'count': 9, 'user_reposted': 0}    {'count': 2826}        False
# 15   {'count': 16, 'user_reposted': 0}   {'count': 95965}        False
# 16   {'count': 30, 'user_reposted': 0}   {'count': 46349}        False
# 17    {'count': 2, 'user_reposted': 0}   {'count': 28586}        False
# 18   {'count': 12, 'user_reposted': 0}   {'count': 44549}        False
# 19    {'count': 2, 'user_reposted': 0}    {'count': 2629}        False
# 20   {'count': 21, 'user_reposted': 0}   {'count': 54030}        False
# 21    {'count': 3, 'user_reposted': 0}    {'count': 3106}        False
# 22   {'count': 25, 'user_reposted': 0}   {'count': 39217}        False
# 23    {'count': 1, 'user_reposted': 0}   {'count': 12221}        False
# 24   {'count': 25, 'user_reposted': 0}   {'count': 78615}        False
# 25    {'count': 5, 'user_reposted': 0}   {'count': 15746}        False
# 26   {'count': 10, 'user_reposted': 0}   {'count': 21784}        False
# 27   {'count': 16, 'user_reposted': 0}   {'count': 41357}        False
# 28    {'count': 9, 'user_reposted': 0}   {'count': 35932}        False
# 29    {'count': 5, 'user_reposted': 0}    {'count': 2364}        False
# 30    {'count': 5, 'user_reposted': 0}    {'count': 2562}        False
# 31   {'count': 11, 'user_reposted': 0}   {'count': 21170}        False
# 32   {'count': 16, 'user_reposted': 0}   {'count': 60227}        False
# 33   {'count': 40, 'user_reposted': 0}   {'count': 17518}        False
# 34   {'count': 14, 'user_reposted': 0}   {'count': 17588}        False
# 35    {'count': 5, 'user_reposted': 0}   {'count': 23636}        False
# 36   {'count': 22, 'user_reposted': 0}    {'count': 2682}        False
# 37    {'count': 2, 'user_reposted': 0}    {'count': 2760}        False
# 38   {'count': 52, 'user_reposted': 0}   {'count': 68389}        False
# 39   {'count': 16, 'user_reposted': 0}   {'count': 52314}        False
# 40    {'count': 5, 'user_reposted': 0}   {'count': 17560}        False
# 41   {'count': 40, 'user_reposted': 0}  {'count': 106583}        False
# 42   {'count': 92, 'user_reposted': 0}   {'count': 66824}        False
# 43    {'count': 3, 'user_reposted': 0}   {'count': 36913}        False
# 44   {'count': 59, 'user_reposted': 0}   {'count': 12255}        False
# 45   {'count': 22, 'user_reposted': 0}   {'count': 40863}        False
# 46  {'count': 117, 'user_reposted': 0}   {'count': 73654}        False
# 47    {'count': 3, 'user_reposted': 0}   {'count': 46144}        False
# 48   {'count': 11, 'user_reposted': 0}   {'count': 25972}        False
# 49   {'count': 17, 'user_reposted': 0}   {'count': 40183}        False
#
#                   donut  short_text_rate                      hash  \
# 0   {'is_donut': False}              0.8  jJ426dvUtyATWNu2PMzRh7Tc
# 1   {'is_donut': False}              0.8  kocLgoZTU3Bg5dVg0cg9aVAB
# 2   {'is_donut': False}              0.8  t-GdKlq83ujBZpXeoRWGER4E
# 3   {'is_donut': False}              0.8  r-5ioV1Fm_tT2RMcQV5ToK0y
# 4   {'is_donut': False}              0.8  LXkVQ9aeeh1tEaGy13UF4Pa_
# 5   {'is_donut': False}              0.8  78TOgdpXGO5WEx6SjUt4wUQb
# 6   {'is_donut': False}              0.8  -EIHOzPYevGGu55KDpA2IsCp
# 7   {'is_donut': False}              0.8  pD3vdZEmZamC1EHJwq1sFzB2
# 8   {'is_donut': False}              0.8  H4qz_bzKRLXuFKVW0jNzahtj
# 9   {'is_donut': False}              0.8  Fxy9w7J6CUI1_1S4OqJE1Nj9
# 10  {'is_donut': False}              0.8  dS59ll5ibDSHsd2-OaGbtVta
# 11  {'is_donut': False}              0.8  WWQNlHfXI4-uwLNN13VqNg8q
# 12  {'is_donut': False}              0.8  H564J_RnfpjJ56L2IeDpz_2H
# 13  {'is_donut': False}              0.8  eEPU34U7PRQsxuevNI--dolA
# 14  {'is_donut': False}              0.8  fZfb9TA0LqLX9aLFDFjnGxvB
# 15  {'is_donut': False}              0.8  TYMI-kC8v2X9jj2lgLp4Fyi8
# 16  {'is_donut': False}              0.8  c-g9TUSoYf-b183Az16nkrO1
# 17  {'is_donut': False}              0.8  i5d6CGIhnLFvlK7WGcUlK1Gh
# 18  {'is_donut': False}              0.8  KkgSV5eh3oeR-k1KfVim9QBs
# 19  {'is_donut': False}              0.8  UUez_o_B7WAbwA0SXj7oJIHY
# 20  {'is_donut': False}              0.8  uSWeS5E875kdbGDawMQcL7au
# 21  {'is_donut': False}              0.8  EI6QgeRGXEeMNgJUBcBA1-20
# 22  {'is_donut': False}              0.8  1HXe721M8yV1IEcf20RbRwIw
# 23  {'is_donut': False}              0.8  Gg2lm9UrGSvKojYPdDel-gty
# 24  {'is_donut': False}              0.8  TMtE7wkOQz2OwTjzRLAQLtml
# 25  {'is_donut': False}              0.8  tr5F0jjklYT_bBHAjFOMQ45C
# 26  {'is_donut': False}              0.8  YwJcvAvRo7a5pgNJ3kTQKkwX
# 27  {'is_donut': False}              0.8  rjQQEPHQO97mr91JtSGQBWWc
# 28  {'is_donut': False}              0.8  mjjprG6Jsqe8DkhHNCgRqVVx
# 29  {'is_donut': False}              0.8  KPoHEKEEe1GRJHyFMcOZcJ4p
# 30  {'is_donut': False}              0.8  eO8lu9hFdOGUWCpOKJlJtN2T
# 31  {'is_donut': False}              0.8  yQRdZSEiJSQ6EmVR-beP0kkU
# 32  {'is_donut': False}              0.8  8Zu4fo_MapHFRP2tpC9GjhYi
# 33  {'is_donut': False}              0.8  Dv7aB_79ht0DpTzDurP0zGa0
# 34  {'is_donut': False}              0.8  KnJ9fZz6l9vfc9J4kCdvYkNj
# 35  {'is_donut': False}              0.8  zTiWRyzBUmWyUlEIKDPj4OK7
# 36  {'is_donut': False}              0.8  H5WOef7kw4fW4AOi5X2KOFU6
# 37  {'is_donut': False}              0.8  jip4hFRHgmNINHGGJKvrYnPW
# 38  {'is_donut': False}              0.8  6E1KW5fO8Hr1fdxcak7XAXcS
# 39  {'is_donut': False}              0.8  -B0MMx-imJ0SY6nddqJqBExg
# 40  {'is_donut': False}              0.8  R6hXGMnQPJ85ySQnSBrA5R2F
# 41  {'is_donut': False}              0.8  Yy6W7thyhaadJ55YzMqCrmbx
# 42  {'is_donut': False}              0.8  ttkl_NB3PSawVdTBIWO-eVnf
# 43  {'is_donut': False}              0.8  duU-9jO-pzItH5biCP06j7iz
# 44  {'is_donut': False}              0.8  Ot_au5Wlmcp9VoW0fUjabc47
# 45  {'is_donut': False}              0.8  ExoXtfQwfyMqu2ZjjrFKdYMj
# 46  {'is_donut': False}              0.8  bCgIOjwNFx1tR1hJCs4NhWUR
# 47  {'is_donut': False}              0.8  27m_NcC0XH5Gp07AU4EbISrZ
# 48  {'is_donut': False}              0.8  A4oJeVZ2L1ZIDXc3eVM3mxXx
# 49  {'is_donut': False}              0.8  QmbKtETbUOJCdBYTETJgy_Ep
#
#           edited  carousel_offset
# 0            NaN              NaN
# 1            NaN              NaN
# 2            NaN              NaN
# 3   1.629283e+09              NaN
# 4            NaN              0.0
# 5            NaN              NaN
# 6            NaN              NaN
# 7   1.629103e+09              NaN
# 8            NaN              NaN
# 9            NaN              NaN
# 10           NaN              NaN
# 11           NaN              NaN
# 12           NaN              0.0
# 13           NaN              NaN
# 14           NaN              NaN
# 15           NaN              NaN
# 16           NaN              0.0
# 17  1.628583e+09              NaN
# 18           NaN              NaN
# 19           NaN              NaN
# 20           NaN              NaN
# 21           NaN              0.0
# 22           NaN              NaN
# 23           NaN              0.0
# 24           NaN              NaN
# 25           NaN              NaN
# 26  1.628246e+09              NaN
# 27           NaN              0.0
# 28           NaN              NaN
# 29           NaN              NaN
# 30           NaN              NaN
# 31           NaN              NaN
# 32           NaN              0.0
# 33           NaN              NaN
# 34           NaN              NaN
# 35           NaN              NaN
# 36  1.627972e+09              NaN
# 37           NaN              NaN
# 38           NaN              NaN
# 39           NaN              NaN
# 40           NaN              0.0
# 41           NaN              NaN
# 42           NaN              0.0
# 43           NaN              NaN
# 44           NaN              NaN
# 45           NaN              NaN
# 46           NaN              0.0
# 47           NaN              NaN
# 48           NaN              NaN
# 49           NaN              NaN

# %%
result_frame = D_frame.loc[:,['date','text']] # Оставляем только два нужных столбца
result_frame.columns = ['Дата поста', 'Текст поста'] # Переименовываем столбцы
result_frame
# Out:
#     Дата поста                                        Текст поста
# 0   2021-08-16  Наш летний диджитал-марафон продолжается 🎁\n \...
# 1   2021-08-19  С появлением искусственного интеллекта тратить...
# 2   2021-08-18  У нас сегодня Нето-викторина 🤩\n\nМы подготови...
# 3   2021-08-18  Запустили курс «Старт в SMM» 🙃\n \nSMM-специал...
# 4   2021-08-17  Вебинар ничем не отличается от любого публично...
# 5   2021-08-17  💼 20 августа в 19:00 на нашем Ютуб-канале прой...
# 6   2021-08-16  Коллаборации с блогерами — один из важных инст...
# 7   2021-08-16  25 августа стартует бесплатный курс «Системный...
# 8   2021-08-15  Ещё немного и лето закончится 🙁 \n \nПредлагае...
# 9   2021-08-14  Летний отпуск может серьёзно ударить по карман...
# 10  2021-08-13  Конец лета уже совсем близко, надеемся, что вы...
# 11  2021-08-13  Как придумывать хорошие заголовки, делать стор...
# 12  2021-08-12  Коммуникабельность, ответственность — это, кон...
# 13  2021-08-12  Современный голосовой ассистент — это реалисти...
# 14  2021-08-11  У нас сегодня Нето-викторина 🤩\n\nМы подготови...
# 15  2021-08-11  Запустили бесплатный курс «Введение в геймдиза...
# 16  2021-08-10  Купите слона! 🐘 \n \nРассказываем, как с помощ...
# 17  2021-08-10  Профессия финансиста неоднородна: существуют р...
# 18  2021-08-09  Выкладывать видео в ТикТок и просто надеяться,...
# 19  2021-08-09  Наш летний диджитал-марафон продолжается 🎁\n \...
# 20  2021-08-09  17 августа стартует бесплатный курс «Первые ша...
# 21  2021-08-08  *партнёрский пост*\n\nКаждый четвёртый выпускн...
# 22  2021-08-08  Мы очень мало знаем о своём мозге 🤯 \nНескольк...
# 23  2021-08-07  Мы часто делимся историями роста наших студент...
# 24  2021-08-07  Мечтаете попасть в реки? 🤪 \n \nСобрали статьи...
# 25  2021-08-06  📅 Составляем список дел до конца лета \n \nДо ...
# 26  2021-08-06  Аналитика не такая сложная, если в ней начать ...
# 27  2021-08-05  Доброго времени суток! 😊 \n \nРассказываем, ка...
# 28  2021-08-05  Перемены бывают в жизни каждого из нас: сменит...
# 29  2021-08-05  Берём любимые снеки и идём смотреть новый роли...
# 30  2021-08-04  У нас сегодня Нето-викторина 🤩\n\nМы подготови...
# 31  2021-08-04  💼 16 августа стартует курс «Как стать продакт-...
# 32  2021-08-03  Что делать, если хочется сменить профессию, но...
# 33  2021-08-03  Сильные тексты важны как в маркетинге, так и в...
# 34  2021-08-02  Популярность софт скилов растёт, потому что эт...
# 35  2021-08-02  Лето в самом разгаре и мы надеемся, что вы не ...
# 36  2021-08-02  Залетаем в реки с нашим бесплатным курсом «Про...
# 37  2021-08-01  Рынок образования претерпел серьёзные изменени...
# 38  2021-08-01  Учиться тоже нужно уметь 🤔 \n \nСобрали книги,...
# 39  2021-07-31  У диджитал-профессий есть свои особенности, о ...
# 40  2021-07-30  Компьютеры появились ещё в прошлом столетии, н...
# 41  2021-07-30  В конце каждого месяца заботливо собираем подб...
# 42  2021-07-29  Работа в диджитал ≠ лежать под пальмой где-ниб...
# 43  2021-07-29  Продолжаем снимать новый формат видео, в котор...
# 44  2021-07-28  Ещё несколько дней и начнётся последний месяц ...
# 45  2021-07-28  👩‍🎨 Запустили бесплатный курс «Как стать дизай...
# 46  2021-07-27  Когда действительно любишь работу, часто бывае...
# 47  2021-07-27  Куда развивать стартап — отвечает предпринимат...
# 48  2021-07-26  Написали конспект по открытой лекции «Как учит...
# 49  2021-07-26  Запустили бесплатный курс «Основы интернет-мар...
