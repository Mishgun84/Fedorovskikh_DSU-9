# %% [markdown]
# ## Задание 1

# %% [markdown]
# Даны 2 переменных, в которых хранятся строки произвольной длины: phrase_1 и phrase_2.
# Напишите код, который проверяет какая из этих строк длиннее.

# %%
phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики'
phrase_2 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
if len(phrase_1) > len(phrase_2):
    print('Фраза 1 длиннее фразы 2')
elif len(phrase_1) < len(phrase_2):
    print('Фраза 2 длиннее фразы 1')
else: print('Фразы равной длины')
# Out:
# Фраза 1 длиннее фразы 2

# %%
phrase_1 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
phrase_2 = 'Насколько проще было бы писать программы, если бы не заказчики'
if len(phrase_1) > len(phrase_2):
    print('Фраза 1 длиннее фразы 2')
elif len(phrase_1) < len(phrase_2):
    print('Фраза 2 длиннее фразы 1')
else: print('Фразы равной длины')
# Out:
# Фраза 2 длиннее фразы 1

# %%
phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики'
phrase_2 = 'Насколько проще было бы писать программы, если бы не заказчики'
if len(phrase_1) > len(phrase_2):
    print('Фраза 1 длиннее фразы 2')
elif len(phrase_1) < len(phrase_2):
    print('Фраза 2 длиннее фразы 1')
else: print('Фразы равной длины')
# Out:
# Фразы равной длины

# %% [markdown]
# ## Задание 2

# %% [markdown]
# Дана переменная, в которой хранится четырехзначное число (год). Необходимо написать программу, которая выведет, является ли данный год високосным или обычным.

# %%
# распределение високосных годов:
# год, номер которого кратен 400, — високосный;
# остальные годы, номер которых кратен 100, — невисокосные (например, годы 1700, 1800, 1900, 2100, 2200, 2300);
# остальные годы, номер которых кратен 4, — високосные

year = 2020
if year % 400 == 0:
    print('Високосный год')
elif year % 100 == 0:
    print('Обычный год')
elif year % 4 == 0:
    print('Високосный год')
else:
    print('Обычный год')
# Out:
# Високосный год

# %%
year = 2019
if year % 400 == 0:
    print('Високосный год')
elif year % 100 == 0:
    print('Обычный год')
elif year % 4 == 0:
    print('Високосный год')
else:
    print('Обычный год')
# Out:
# Обычный год

# %%
year = 1700
if year % 400 == 0:
    print('Високосный год')
elif year % 100 == 0:
    print('Обычный год')
elif year % 4 == 0:
    print('Високосный год')
else:
    print('Обычный год')
# Out:
# Обычный год

# %% [markdown]
# ## Задание 3

# %% [markdown]
# Необходимо написать программу, которая будет запрашивать у пользователя месяц и дату рождения и выводить соответствующий знак зодиака.

# %%
# Распределение знаков по датам (взято из Википедии):
# Водолей:  21 января - 19 февраля
# Рыбы:     20 февраля - 20 марта
# Овен:     21 марта - 20 апреля
# Телец:    21 апреля - 21 мая
# Близнецы: 22 мая - 21 июня
# Рак:      22 июня - 22 июля
# Лев:      23 июля - 21 августа
# Дева:     22 августа - 23 сентября
# Весы:     24 сентября - 23 октября
# Скорпион: 24 октября - 22 ноября
# Стрелец:  23 ноября - 22 декабря
# Козерог:  23 декабря - 20 января


day = int(input('Введите день: '))
month = input('Введите месяц: ')
if (31 >= day >= 21 and (month == 'Январь' or month == 'январь')) or (1 <= day <= 19 and (month == 'Февраль' or month == 'февраль')):
    print('Ваш знак зодиака: Водолей')
elif (29 >= day >= 20 and (month == 'Февраль' or month == 'февраль')) or (1 <= day <= 20 and (month == 'Март' or month == 'март')):
    print('Ваш знак зодиака: Рыбы')
elif (31 >= day >= 21 and (month == 'Март' or month == 'март')) or (1 <= day <= 20 and (month == 'Апрель' or month == 'апрель')):
    print('Ваш знак зодиака: Овен')
elif (30 >= day >= 21 and (month == 'Апрель' or month == 'апрель')) or (1 <= day <= 21 and (month == 'Май' or month == 'май')):
    print('Ваш знак зодиака: Телец')
elif (31 >= day >= 22 and (month == 'Май' or month == 'май')) or (1 <= day <= 21 and (month == 'Июнь' or month == 'июнь')):
    print('Ваш знак зодиака: Близнецы')
elif (30 >= day >= 22 and (month == 'Июнь' or month == 'июнь')) or (1 <= day <= 22 and (month == 'Июль' or month == 'июль')):
    print('Ваш знак зодиака: Рак')
elif (31 >= day >= 23 and (month == 'Июль' or month == 'июль')) or (1 <= day <= 21 and (month == 'Август' or month == 'август')):
    print('Ваш знак зодиака: Лев')
elif (31 >= day >= 22 and (month == 'Август' or month == 'август')) or (1 <= day <= 23 and (month == 'Сентябрь' or month == 'сентябрь')):
    print('Ваш знак зодиака: Дева')
elif (30 >= day >= 24 and (month == 'Сентябрь' or month == 'сентябрь')) or (1 <= day <= 23 and (month == 'Октябрь' or month == 'октябрь')):
    print('Ваш знак зодиака: Весы')
elif (31 >= day >= 24 and (month == 'Октябрь' or month == 'октябрь')) or (1 <= day <= 22 and (month == 'Ноябрь' or month == 'ноябрь')):
    print('Ваш знак зодиака: Скорпион')
elif (30 >= day >= 23 and (month == 'Ноябрь' or month == 'ноябрь')) or (1 <= day <= 22 and (month == 'Декабрь' or month == 'декабрь')):
    print('Ваш знак зодиака: Стрелец')
elif (31 >= day >= 23 and (month == 'Декабрь' or month == 'декабрь')) or (1 <= day <= 20 and (month == 'Январь' or month == 'январь')):
    print('Ваш знак зодиака: Козерог')   
else:
    print('Еще раз проверьте правильно ли Вы ввели число и название месяца')
# Out:
# Введите день: 01
# Введите месяц: январь
# Ваш знак зодиака: Козерог

# %% [markdown]
# ## Задание 4

# %% [markdown]
# Вам нужно написать программу для подбора упаковок по размерам товара. Размеры (ширина, длина, высота) хранятся в переменных (в сантиметрах):
#
# Используйте следующие правила:
#
# если каждое из трех измерений менее 15 сантиметров, то выведите на экран "Коробка №1";
#
# если хотя бы одно из измерений больше 15 сантиметров, но менее 50 сантиметров, то выводите "Коробка №2";
#
# если длина товара больше 2 метров, то выводите "Упаковка для лыж";
#
# во всех остальных случаях выводите "Стандартная коробка №3".

# %%
width = float(input('Введите ширину коробки (см): '))
length = float(input('Введите длину коробки (см): '))
height = float(input('Введите высоту коробки (см): '))

if width < 15 and length < 15 and height < 15:
    print('Коробка №1')
elif width < 50 and length < 50 and height < 50:
    print('Коробка №2')
elif length > 200:
    print('Упаковка для лыж')
else:
    print('Стандартная коробка №3')
# Out:
# Введите ширину коробки (см): 5
# Введите длину коробки (см): 200.1
# Введите высоту коробки (см): 4
# Упаковка для лыж

# %% [markdown]
# ## Задание 5 (необязательное)

# %% [markdown]
# Дана переменная, в которой хранится шестизначное число (номер проездного билета). Напишите программу, которая будет определять, является ли данный билет "счастливым". Билет считается счастливым, если сумма первых трех цифр совпадает с суммой последних трех цифр номера.

# %%
number = 913571
if ((number % 10) + ((number // 10) % 10) + ((number // 100) % 10)) == (((number // 1000) % 10) + ((number // 10000) % 10) + (number // 100000)):
    print('Счастливый билет')
else:
    print('Несчастливый билет')
# Out:
# Счастливый билет

# %% [markdown]
# ## Задание 6 (необязательное)

# %% [markdown]
# Напишите программу, которая сможет вычислять площади трех фигур (круг, треугольник и прямоугольник). Тип фигуры запрашиваем через пользовательский ввод, после чего делаем запрос характеристик фигуры:
#
# если пользователь выбрал круг, запрашиваем его радиус,
#
# если треугольник – длины трех его сторон;
#
# если прямоугольник – длины двух его сторон.

# %%
figure = input('Для какой фигуры будем вычислять площадь? Варианты: круг, треугольник, прямоугольник.    ')
if figure == 'круг':
    radius = float(input('Укажите радиус круга в см: '))
    print('Площадь круга равна: {:.2f} кв.см.'.format(3.141592653589793 * (radius ** 2)))
elif figure == 'треугольник':
    a = float(input('Укажите в см длину стороны a :  '))
    b = float(input('Укажите в см длину стороны b :  '))
    c = float(input('Укажите в см длину стороны c :  '))
    print('Площадь треугольника равна: {:.2f} кв.см.'.format((((a + b +c) * (a + b - c) * (b + c - a) * (a + c - b)) ** 0.5) / 4 ))
elif figure == 'прямоугольник':
    a = float(input('Укажите в см длину стороны a :  '))
    b = float(input('Укажите в см длину стороны b :  '))
    print('Площадь прямоугольника равна: {:.2f} кв.см.'.format(a * b))
else:
    print('Еще раз проверьте правильно ли Вы ввели название фигуры')
# Out:
# Для какой фигуры будем вычислять площадь? Варианты: круг, треугольник, прямоугольник.    треугольник
# Укажите в см длину стороны a :  2
# Укажите в см длину стороны b :  2
# Укажите в см длину стороны c :  3
# Площадь треугольника равна: 1.98 кв.см.
